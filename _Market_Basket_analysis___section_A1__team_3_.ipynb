# %% [markdown]
# ## **Smart Charging Network Planning: A Data-Driven Strategy for EV Development in Washington State**
#
# Group - 3
#
# Team Members: Fangzhou Zheng, Haojiang Wu, Yixi Yu, Pranaya Bindu Buyya

# %% [markdown]
# ###**Introduction**

# %% [markdown]
# ### **Problem Statement**
# The increasing penetration of electric vehicles (EVs) presents significant challenges in charging infrastructure planning, geographic disparities in adoption, and policy effectiveness. Despite a 35% growth in EV sales (IEA, 2023), inadequate charging infrastructure remains a key barrier to widespread adoption (McKinsey, 2022). Moreover, most of studies do not consider EV distribution, location accessibility, and policy incentives together. Which leads to inefficient resource use and ineffective policies.
#
# This study aims to analyze EV distribution, identify high-demand charging areas, and evaluate policy impact. The findings will:
#
# * help policymakers assess the effectiveness of incentives like the Clean Alternative Fuel Vehicle (CAFV) program and make better infrastructure decisions.
# * help energy providers optimize charging station locations to improve usage efficiency.
# * help automakers understand regional demand patterns to refine marketing strategies.
#
# By applying unsupervised machine learning methods, such as clustering and association rule mining, this study will uncover key trends in EV adoption. The results will offer data-driven insights to assist local government in optimizing EV deployment and infrastructure planning in Washington State to better serve local citizens.

# %% [markdown]
# ### **Data Source**
#
# **Source:** The dataset is made available for public release by the Washington Open Data Portal, providing up-to-date records of registered electric vehicles within the state.
#
# **Dataset URL:** https://drive.google.com/file/d/1iLFacW1f3ENf4u6t4VgsW6GaeNn99za_/view?usp=drive_link

# %% [markdown]
# **Data Dictionary:**
#
# This dataset provides a comprehensive list of electric vehicles (EVs) registered in Washington State, including vehicle details, geographic location, and policy data. The data is taken from the Washington State Department of Licensing (DOL) and updated from time to time to reflect the latest EV registrations.
#
# Dataset Size: approximately 51.7 MB
#
# Number of Records: 22,392 rows (one for each EV registration)
#
# Number of Attributes: 17 columns

# %% [markdown]
# | **Feature Name**               | **Description**                                           | **Data Type**                |
# |--------------------------------|-----------------------------------------------------------|------------------------------|
# | **VIN (1-10)**                 | First 10 digits of the Vehicle Identification Number      | Categorical                  |
# | **County**                     | County where the EV is registered                        | Categorical                  |
# | **City**                       | City of EV registration                                  | Categorical                  |
# | **State**                      | State abbreviation                                       | Categorical                  |
# | **Postal Code**                | ZIP code where the vehicle is registered                 | Categorical (Numeric)        |
# | **Model Year**                 | Year the vehicle was manufactured                        | Numeric                      |
# | **Make**                       | Vehicle manufacturer                                     | Categorical                  |
# | **Model**                      | Specific model of the EV                                 | Categorical                  |
# | **Electric Vehicle Type**       | EV classification (Battery or Hybrid)                   | Categorical                  |
# | **CAFV Eligibility**           | Eligibility for Clean Alternative Fuel Vehicle incentives | Categorical                  |
# | **Electric Range**             | Estimated driving range on a full charge (in miles)     | Numeric                      |
# | **Base MSRP**                  | Manufacturer’s Suggested Retail Price                   | Numeric                      |
# | **Legislative District**       | Washington legislative district                          | Categorical (Numeric)        |
# |**DOL Vehicle ID**  |Unique number assigned to each vehicle by Department of Licensing for identification purposes| Numeric|
# | **Vehicle Location**           | Geographic coordinates (latitude & longitude)           | Categorical (Converted to Numeric) |
# | **Electric Utility**           | Power provider supplying electricity to the EV owner    | Categorical                  |
# | **2020 Census Tract**         | Census demographic data reference                       | Categorical (Numeric)        |

# %% [markdown]
# ## **Step 1: Data Cleaning & Preprocessing**

# %%
#import data
import pandas as pd
import numpy as np

url = 'https://drive.google.com/uc?export=download&id=1iLFacW1f3ENf4u6t4VgsW6GaeNn99za_'
df = pd.read_csv(url)
df.head()
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  1C4JJXP66P     Kitsap       Poulsbo    WA      98370.0        2023
# 1  1G1FX6S08K  Snohomish  Lake Stevens    WA      98258.0        2019
# 2  WBY1Z2C58F       King       Seattle    WA      98116.0        2015
# 3  5YJ3E1EBXK       King       Seattle    WA      98178.0        2019
# 4  5YJSA1V24F     Yakima         Selah    WA      98942.0        2015
#
#         Make     Model                   Electric Vehicle Type  \
# 0       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  CHEVROLET   BOLT EV          Battery Electric Vehicle (BEV)
# 2        BMW        I3          Battery Electric Vehicle (BEV)
# 3      TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 4      TESLA   MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Not eligible due to low battery range            21.0
# 1           Clean Alternative Fuel Vehicle Eligible           238.0
# 2           Clean Alternative Fuel Vehicle Eligible            81.0
# 3           Clean Alternative Fuel Vehicle Eligible           220.0
# 4           Clean Alternative Fuel Vehicle Eligible           208.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  23.0       258127145
# 1        0.0                  44.0         4735426
# 2        0.0                  34.0       272697666
# 3        0.0                  37.0       477309682
# 4        0.0                  15.0       258112970
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 1  POINT (-122.06402 48.01497)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.41067 47.57894)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3  POINT (-122.23825 47.49461)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-120.53145 46.65405)                                    PACIFICORP
#
#    2020 Census Tract
# 0       5.303509e+10
# 1       5.306105e+10
# 2       5.303301e+10
# 3       5.303301e+10
# 4       5.307700e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223995 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         223995 non-null  object
#  1   County                                             223992 non-null  object
#  2   City                                               223992 non-null  object
#  3   State                                              223995 non-null  object
#  4   Postal Code                                        223992 non-null  float64
#  5   Model Year                                         223995 non-null  int64
#  6   Make                                               223995 non-null  object
#  7   Model                                              223995 non-null  object
#  8   Electric Vehicle Type                              223995 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  223995 non-null  object
#  10  Electric Range                                     223977 non-null  float64
#  11  Base MSRP                                          223977 non-null  float64
#  12  Legislative District                               223521 non-null  float64
#  13  DOL Vehicle ID                                     223995 non-null  int64
#  14  Vehicle Location                                   223985 non-null  object
#  15  Electric Utility                                   223992 non-null  object
#  16  2020 Census Tract                                  223992 non-null  float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 29.1+ MB

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                        18
# Base MSRP                                             18
# Legislative District                                 474
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       3
# 2020 Census Tract                                      3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().count()
# Out:
# VIN (1-10)                                           223496
# County                                               223496
# City                                                 223496
# State                                                223496
# Postal Code                                          223496
# Model Year                                           223496
# Make                                                 223496
# Model                                                223496
# Electric Vehicle Type                                223496
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    223496
# Electric Range                                       223496
# Base MSRP                                            223496
# Legislative District                                 223496
# DOL Vehicle ID                                       223496
# Vehicle Location                                     223496
# Electric Utility                                     223496
# 2020 Census Tract                                    223496
# dtype: int64

# %%
df[['Longitude', 'Latitude']] = df['Vehicle Location'].str.extract(r'POINT \((-?\d+\.\d+) (-?\d+\.\d+)\)')
df['Longitude'] = df['Longitude'].astype(float)
df['Latitude'] = df['Latitude'].astype(float)
df.drop(columns=['Vehicle Location'], inplace=True)

df
# Out:
#         VIN (1-10)     County              City State  Postal Code  \
# 0       1C4JJXP66P     Kitsap           Poulsbo    WA      98370.0
# 1       1G1FX6S08K  Snohomish      Lake Stevens    WA      98258.0
# 2       WBY1Z2C58F       King           Seattle    WA      98116.0
# 3       5YJ3E1EBXK       King           Seattle    WA      98178.0
# 4       5YJSA1V24F     Yakima             Selah    WA      98942.0
# ...            ...        ...               ...   ...          ...
# 223990  7SAYGDEE4R     Pierce          Puyallup    WA      98374.0
# 223991  WBY8P2C00M  Snohomish      Lake Stevens    WA      98258.0
# 223992  JN1AZ0CP3B     Pierce  University Place    WA      98466.0
# 223993  5YJ3E1EA2R     Pierce          Puyallup    WA      98374.0
# 223994  WBY8P8C57K       King       Woodinville    WA      98072.0
#
#         Model Year       Make     Model  \
# 0             2023       JEEP  WRANGLER
# 1             2019  CHEVROLET   BOLT EV
# 2             2015        BMW        I3
# 3             2019      TESLA   MODEL 3
# 4             2015      TESLA   MODEL S
# ...            ...        ...       ...
# 223990        2024      TESLA   MODEL Y
# 223991        2021        BMW        I3
# 223992        2011     NISSAN      LEAF
# 223993        2024      TESLA   MODEL 3
# 223994        2019        BMW        I3
#
#                          Electric Vehicle Type  \
# 0       Plug-in Hybrid Electric Vehicle (PHEV)
# 1               Battery Electric Vehicle (BEV)
# 2               Battery Electric Vehicle (BEV)
# 3               Battery Electric Vehicle (BEV)
# 4               Battery Electric Vehicle (BEV)
# ...                                        ...
# 223990          Battery Electric Vehicle (BEV)
# 223991          Battery Electric Vehicle (BEV)
# 223992          Battery Electric Vehicle (BEV)
# 223993          Battery Electric Vehicle (BEV)
# 223994  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                   Not eligible due to low battery range            21.0
# 1                 Clean Alternative Fuel Vehicle Eligible           238.0
# 2                 Clean Alternative Fuel Vehicle Eligible            81.0
# 3                 Clean Alternative Fuel Vehicle Eligible           220.0
# 4                 Clean Alternative Fuel Vehicle Eligible           208.0
# ...                                                   ...             ...
# 223990  Eligibility unknown as battery range has not b...             0.0
# 223991  Eligibility unknown as battery range has not b...             0.0
# 223992            Clean Alternative Fuel Vehicle Eligible            73.0
# 223993  Eligibility unknown as battery range has not b...             0.0
# 223994            Clean Alternative Fuel Vehicle Eligible           126.0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0             0.0                  23.0       258127145
# 1             0.0                  44.0         4735426
# 2             0.0                  34.0       272697666
# 3             0.0                  37.0       477309682
# 4             0.0                  15.0       258112970
# ...           ...                   ...             ...
# 223990        0.0                   2.0       264662359
# 223991        0.0                  44.0       157728168
# 223992        0.0                  28.0       261733433
# 223993        0.0                  25.0       275283487
# 223994        0.0                  45.0       267288801
#
#                                          Electric Utility  2020 Census Tract  \
# 0                                  PUGET SOUND ENERGY INC       5.303509e+10
# 1                                  PUGET SOUND ENERGY INC       5.306105e+10
# 2            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                              PACIFICORP       5.307700e+10
# ...                                                   ...                ...
# 223990      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 223991                             PUGET SOUND ENERGY INC       5.306105e+10
# 223992  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 223993      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 223994      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
#
#         Longitude  Latitude
# 0      -122.64681  47.73689
# 1      -122.06402  48.01497
# 2      -122.41067  47.57894
# 3      -122.23825  47.49461
# 4      -120.53145  46.65405
# ...           ...       ...
# 223990 -122.27575  47.13959
# 223991 -122.06402  48.01497
# 223992 -122.53756  47.23165
# 223993 -122.27575  47.13959
# 223994 -122.15545  47.75448
#
# [223496 rows x 18 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223496 entries, 0 to 223994
# Data columns (total 18 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         223496 non-null  object
#  1   County                                             223496 non-null  object
#  2   City                                               223496 non-null  object
#  3   State                                              223496 non-null  object
#  4   Postal Code                                        223496 non-null  float64
#  5   Model Year                                         223496 non-null  int64
#  6   Make                                               223496 non-null  object
#  7   Model                                              223496 non-null  object
#  8   Electric Vehicle Type                              223496 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  223496 non-null  object
#  10  Electric Range                                     223496 non-null  float64
#  11  Base MSRP                                          223496 non-null  float64
#  12  Legislative District                               223496 non-null  float64
#  13  DOL Vehicle ID                                     223496 non-null  int64
#  14  Electric Utility                                   223496 non-null  object
#  15  2020 Census Tract                                  223496 non-null  float64
#  16  Longitude                                          223496 non-null  float64
#  17  Latitude                                           223496 non-null  float64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 32.4+ MB

# %%
df[df.select_dtypes(include=['object']).columns] = df.select_dtypes(include=['object']).apply(lambda x: x.astype('category'))

# %% [markdown]
# ##**Step 2: Exploratory Data Analysis: Looking into Interesting Insights**
#
# For this project, we are performing Electric Vehicle (EV) adoption in Washington State based on a dataset available.
#
# The primary goal of this EDA is to gain insights into EV distribution, model popularity, infrastructure availability, and policy impact. Through statistical analysis and visualizations, we aim to answer the following primary questions:

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  223496.000000  223496.000000   223496.000000  223496.000000
# mean    98269.193739    2021.265266       47.726599     828.337957
# std       310.659079       2.989873       84.975652    7366.061719
# min     98001.000000    1999.000000        0.000000       0.000000
# 25%     98052.000000    2020.000000        0.000000       0.000000
# 50%     98126.000000    2022.000000        0.000000       0.000000
# 75%     98375.000000    2023.000000       39.000000       0.000000
# max     99403.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract      Longitude  \
# count         223496.000000    2.234960e+05       2.234960e+05  223496.000000
# mean              28.876356    2.329479e+08       5.304006e+10    -122.063454
# std               14.911001    6.884834e+07       1.644383e+07       1.054376
# min                1.000000    4.385000e+03       5.300195e+10    -124.627350
# 25%               17.000000    2.008299e+08       5.303301e+10    -122.401990
# 50%               32.000000    2.488410e+08       5.303303e+10    -122.291790
# 75%               42.000000    2.674022e+08       5.305307e+10    -122.131580
# max               49.000000    4.792548e+08       5.307794e+10    -117.043980
#
#             Latitude
# count  223496.000000
# mean       47.458093
# std         0.619611
# min        45.579230
# 25%        47.328000
# 50%        47.603260
# 75%        47.722380
# max        48.999760

# %% [markdown]
# ### **a) What is the relative preference for Plug-in Hybrid Electric Vehicles (PHEVs) and Battery Electric Vehicles (BEVs)?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
sns.countplot(y='Electric Vehicle Type', data=df, palette='viridis', hue = 'Electric Vehicle Type')
plt.title('Electric Vehicle Type Distribution')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# **Observations:**
#
# Battery Electric Vehicles (BEVs) make up ~80% of the sample, and Plug-in Hybrid Electric Vehicles (PHEVs) make up a paltry ~20%. This indicates that there is high consumer demand for electric vehicles over hybrids, most likely due to improved charging infrastructure, longer battery lifespan, and government incentives favoring BEVs. While PHEVs have a niche market share, the trend is towards a continued move towards fully electric mobility as technology and infrastructure improve.

# %% [markdown]
# ###**b) Which firms dominate the EV market?**

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
sns.countplot(y='Make', data=df, palette='magma', hue = 'Make')
plt.title('Vehicle Count by Make')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# **Observations:**
#
# Tesla is the EV leader by a significant margin over the next largest firms, with Chevrolet and Nissan following closely behind as significant players in the affordable EV space. Firms like Ford, Toyota, and Hyundai exist but have a relatively small share of the market. Tesla's leadership might be a result of extensive charging stations, superior brand awareness, and superior battery technology, whereas Chevrolet and Nissan exist as evidence of sustained demand for affordable EVs.

# %% [markdown]
# ###**c) How has the adoption of EV evolved over the years?**

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
sns.countplot(x='Model Year', data=df, palette='rocket', hue = 'Model Year')
plt.title('Vehicle Distribution by Model Year')
plt.show()

# %% [markdown]
# **Observations:**
#
# The majority of the registered EVs are made after 2018, with 2022 and 2023 representing the peak. EVs made before 2010 are rare, indicating that early uptake was unpopular and started picking up pace only in the last decade. The sharp spike in registrations over recent years is a reflection of the increase in battery technology, decreased affordability, and heightened policy support that have been fueling the relatively faster growth of the EV market.

# %% [markdown]
# ###**d) Where is EV adoption geographically concentrated?**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df["Longitude"], df["Latitude"], alpha=0.5, c='red', s=10)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Vehicle Geographical Distribution")
plt.grid(True)
plt.show()

# %% [markdown]
# **Observations:**
#
# EV adoption is most dense in urban centers, with Seattle, Bellevue, and Tacoma. Rural regions, particularly eastern Washington, are low in adoption, likely due to infrequent charging infrastructure and reduced EV incentives. The most dense EV adoption tracks along the I-5 corridor correspond to population density and infrastructure availability, and the outlying regions are underserved.

# %% [markdown]
# ###**e) How EV Adoption Varies by County**

# %%
county_vehicle_counts = df['County'].value_counts()

plt.figure(figsize=(12, 6))
county_vehicle_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Number of Electric Vehicles per County', fontsize=14)
plt.xlabel('County', fontsize=12)
plt.ylabel('Number of Vehicles', fontsize=12)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# **Observations:**
#
# King County has the most electric vehicles by a huge margin, followed by Snohomish and Pierce. Most counties have a much smaller EV presence, which suggests that EV adoption is highly concentrated in a few key areas. It is possibly due to factors like charging infrastructure availability, population density, or government incentives.

# %% [markdown]
# ###**f) How do government incentives like CAFV eligibility impact adoption?**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cafv_counts = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()

plt.figure(figsize=(8, 8))
sns.set_style("whitegrid")

sns.barplot(x=cafv_counts.index, y=cafv_counts.values, palette="coolwarm", order=cafv_counts.index)

plt.title('Clean Alternative Fuel Vehicle (CAFV) Eligibility')
plt.xlabel('CAFV Eligibility')
plt.ylabel('Number of Vehicles')

for i, count in enumerate(cafv_counts.values):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-150-f8b18fc486b8>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cafv_counts.index, y=cafv_counts.values, palette="coolwarm", order=cafv_counts.index)

# %% [markdown]
# **Observations:**
#
# Most EVs (130,199) are CAFV-eligible, with 71,258 excluded. This suggests government incentives as a significant factor in EV adoption since most vehicles qualify for state programs offering cash incentives. The high proportion of CAFV-eligible cars indicates the success of policy-driven adoption efforts, though the proportion excluded warns of possible limits in accessibility of incentives.

# %% [markdown]
# ## **Step 6: Exploring EV Distribution and Patterns: Brand, Model, and Regional Insights**
#
# **Association Rule Mining**

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df_filtered = df[['Make', 'Model', 'Model Year', 'City', 'County']].copy()

# Ensure Model Year is numeric
df_filtered['Model Year'] = pd.to_numeric(df_filtered['Model Year'], errors='coerce')

bins = list(range(1999, 2026,2))
labels = [f"{bins[i]}-{bins[i+1]-1}" for i in range(len(bins)-1)]

df_filtered['Model Year'] = pd.cut(df_filtered['Model Year'], bins=bins, labels=labels, right=True)

df_filtered
# Out:
#              Make     Model Model Year              City     County
# 0            JEEP  WRANGLER  2021-2022           Poulsbo     Kitsap
# 1       CHEVROLET   BOLT EV  2017-2018      Lake Stevens  Snohomish
# 2             BMW        I3  2013-2014           Seattle       King
# 3           TESLA   MODEL 3  2017-2018           Seattle       King
# 4           TESLA   MODEL S  2013-2014             Selah     Yakima
# ...           ...       ...        ...               ...        ...
# 223990      TESLA   MODEL Y  2023-2024          Puyallup     Pierce
# 223991        BMW        I3  2019-2020      Lake Stevens  Snohomish
# 223992     NISSAN      LEAF  2009-2010  University Place     Pierce
# 223993      TESLA   MODEL 3  2023-2024          Puyallup     Pierce
# 223994        BMW        I3  2017-2018       Woodinville       King
#
# [223496 rows x 5 columns]

# %%
df_transactions = df_filtered.astype(str).values.tolist()
df_transactions
# Out:
# [['JEEP', 'WRANGLER', '2021-2022', 'Poulsbo', 'Kitsap'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Lake Stevens', 'Snohomish'],
#  ['BMW', 'I3', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Selah', 'Yakima'],
#  ['JEEP', 'WRANGLER', '2019-2020', 'Bremerton', 'Kitsap'],
#  ['BMW', '530E', '2017-2018', 'Lacey', 'Thurston'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Kent', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Lynnwood', 'Snohomish'],
#  ['LEXUS', 'RZ', '2021-2022', 'Olalla', 'Kitsap'],
#  ['KIA', 'EV6', '2023-2024', 'Poulsbo', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2019-2020', 'Suquamish', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Issaquah', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Poulsbo', 'Kitsap'],
#  ['POLESTAR', 'PS2', '2019-2020', 'Oak Harbor', 'Island'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Kenmore', 'King'],
#  ['HYUNDAI', 'SANTA FE', '2021-2022', 'Poulsbo', 'Kitsap'],
#  ['BMW', 'I3', '2013-2014', 'Seabeck', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Toppenish', 'Yakima'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Sammamish', 'King'],
#  ['JEEP', 'WRANGLER', '2023-2024', 'Port Orchard', 'Kitsap'],
#  ['BMW', '330E', '2017-2018', 'Poulsbo', 'Kitsap'],
#  ['TOYOTA', 'PRIUS PRIME', '2017-2018', 'Silverdale', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['RIVIAN', 'R1T', '2021-2022', 'Yelm', 'Thurston'],
#  ['VOLVO', 'XC60', '2021-2022', 'Olympia', 'Thurston'],
#  ['BMW', 'X5', '2019-2020', 'Seattle', 'King'],
#  ['FIAT', '500', '2013-2014', 'Yelm', 'Thurston'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Bainbridge Island', 'Kitsap'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Poulsbo', 'Kitsap'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Edmonds', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bothell', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bothell', 'Snohomish'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Poulsbo', 'Kitsap'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Olympia', 'Thurston'],
#  ['KIA', 'NIRO', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kent', 'King'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Poulsbo', 'Kitsap'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Sammamish', 'King'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Poulsbo', 'Kitsap'],
#  ['VOLVO', 'XC90', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Tumwater', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Redmond', 'King'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Stanwood', 'Snohomish'],
#  ['RIVIAN', 'R1S', '2021-2022', 'Bothell', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2009-2010', 'Sammamish', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bothell', 'Snohomish'],
#  ['AUDI', 'E-TRON', '2021-2022', 'Yakima', 'Yakima'],
#  ['LEXUS', 'RX', '2023-2024', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2019-2020', 'Poulsbo', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Edmonds', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Yakima', 'Yakima'],
#  ['BMW', 'I3', '2013-2014', 'Bremerton', 'Kitsap'],
#  ['BMW', 'IX', '2023-2024', 'Selah', 'Yakima'],
#  ['JEEP', 'WRANGLER', '2021-2022', 'Poulsbo', 'Kitsap'],
#  ['BMW', 'X5', '2023-2024', 'Seattle', 'King'],
#  ['KIA', 'NIRO', '2023-2024', 'Kingston', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bremerton', 'Kitsap'],
#  ['KIA', 'NIRO', '2019-2020', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Snohomish', 'Snohomish'],
#  ['KIA', 'EV6', '2021-2022', 'Poulsbo', 'Kitsap'],
#  ['RIVIAN', 'R1S', '2023-2024', 'Yakima', 'Yakima'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Redmond', 'King'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Snohomish', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Everett', 'Snohomish'],
#  ['CHRYSLER', 'PACIFICA', '2017-2018', 'Poulsbo', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bothell', 'Snohomish'],
#  ['CHEVROLET', 'BOLT EV', '2015-2016', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Sammamish', 'King'],
#  ['HYUNDAI', 'IONIQ', '2019-2020', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Brier', 'Snohomish'],
#  ['KIA', 'SOUL', '2015-2016', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Port Orchard', 'Kitsap'],
#  ['FORD', 'F-150', '2021-2022', 'Marysville', 'Snohomish'],
#  ['BMW', '330E', '2023-2024', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Freeland', 'Island'],
#  ['KIA', 'NIRO', '2021-2022', 'Chewelah', 'Stevens'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Lake Stevens', 'Snohomish'],
#  ['AUDI', 'Q5 E', '2023-2024', 'Olympia', 'Thurston'],
#  ['JEEP', 'WRANGLER', '2021-2022', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bremerton', 'Kitsap'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Lynnwood', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Auburn', 'King'],
#  ['VOLVO', 'XC90', '2021-2022', 'Port Orchard', 'Kitsap'],
#  ['KIA', 'SORENTO', '2021-2022', 'Marysville', 'Snohomish'],
#  ['CHEVROLET', 'BOLT EV', '2015-2016', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Port Orchard', 'Kitsap'],
#  ['JEEP', 'GRAND CHEROKEE', '2023-2024', 'Quincy', 'Grant'],
#  ['JEEP', 'WRANGLER', '2021-2022', 'Moses Lake', 'Grant'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Everett', 'Snohomish'],
#  ['TOYOTA', 'RAV4 PRIME', '2023-2024', 'Colville', 'Stevens'],
#  ['KIA', 'SORENTO', '2021-2022', 'Bothell', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Burien', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Langley', 'Island'],
#  ['FIAT', '500', '2015-2016', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Woodinville', 'Snohomish'],
#  ['BMW', 'X5', '2021-2022', 'Seattle', 'King'],
#  ['BMW', 'I3', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Selah', 'Yakima'],
#  ['KIA', 'NIRO', '2017-2018', 'Lacey', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['BMW', 'X5', '2021-2022', 'Seattle', 'King'],
#  ['BMW', '530E', '2019-2020', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Tumwater', 'Thurston'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Olympia', 'Thurston'],
#  ['CHEVROLET', 'VOLT', '2009-2010', 'Lacey', 'Thurston'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Ellensburg', 'Kittitas'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Edmonds', 'Snohomish'],
#  ['KIA', 'SOUL', '2015-2016', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Edmonds', 'Snohomish'],
#  ['KIA', 'SOUL', '2015-2016', 'Olympia', 'Thurston'],
#  ['MERCEDES-BENZ', 'GLC-CLASS', '2017-2018', 'Bothell', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Tumwater', 'Thurston'],
#  ['NISSAN', 'LEAF', '2023-2024', 'Zillah', 'Yakima'],
#  ['VOLVO', 'XC90', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Wapato', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Duvall', 'King'],
#  ['KIA', 'SORENTO', '2023-2024', 'Olympia', 'Thurston'],
#  ['AUDI', 'A3', '2015-2016', 'Burien', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Issaquah', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2023-2024', 'Lacey', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['MAZDA', 'CX-70', '2023-2024', 'Cheney', 'Spokane'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Pullman', 'Whitman'],
#  ['FIAT', '500', '2015-2016', 'Bow', 'Skagit'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Rockford', 'Spokane'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Hunters', 'Stevens'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Olympia', 'Thurston'],
#  ['MAZDA', 'CX-90', '2023-2024', 'East Wenatchee', 'Douglas'],
#  ['BMW', 'I3', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Bremerton', 'Kitsap'],
#  ['KIA', 'NIRO', '2017-2018', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Langley', 'Island'],
#  ['HONDA', 'CLARITY', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['TOYOTA', 'RAV4 PRIME', '2019-2020', 'Spokane', 'Spokane'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Yakima', 'Yakima'],
#  ['FORD', 'C-MAX', '2011-2012', 'Monroe', 'Snohomish'],
#  ['MITSUBISHI', 'OUTLANDER', '2017-2018', 'Pullman', 'Whitman'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Mount Vernon', 'Skagit'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['TOYOTA', 'RAV4 PRIME', '2023-2024', 'Snohomish', 'Snohomish'],
#  ['TOYOTA', 'PRIUS PLUG-IN', '2011-2012', 'College Place', 'Walla Walla'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Port Orchard', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bothell', 'Snohomish'],
#  ['JEEP', 'WRANGLER', '2023-2024', 'Anacortes', 'Skagit'],
#  ['AUDI', 'Q5', '2021-2022', 'Cle Elum', 'Kittitas'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Othello', 'Grant'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Wenatchee', 'Chelan'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Colville', 'Stevens'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TOYOTA', 'PRIUS PRIME', '2015-2016', 'Bothell', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Monroe', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Yelm', 'Thurston'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Yelm', 'Thurston'],
#  ['LEXUS', 'NX', '2023-2024', 'Bothell', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Renton', 'King'],
#  ['FORD', 'C-MAX', '2013-2014', 'Greenbank', 'Island'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Palouse', 'Whitman'],
#  ['CHRYSLER', 'PACIFICA', '2021-2022', 'Moses Lake', 'Grant'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Redmond', 'King'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Everett', 'Snohomish'],
#  ['BMW', 'X5', '2021-2022', 'Chelan', 'Chelan'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Mount Vernon', 'Skagit'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Marysville', 'Snohomish'],
#  ['AUDI', 'Q5 E', '2021-2022', 'Edmonds', 'Snohomish'],
#  ['KIA', 'SOUL', '2015-2016', 'Lynnwood', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Fall City', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Lake Stevens', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Bow', 'Skagit'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Clinton', 'Island'],
#  ['CHRYSLER', 'PACIFICA', '2019-2020', 'Lake Stevens', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Oak Harbor', 'Island'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Yakima', 'Yakima'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Anacortes', 'Skagit'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Mount Vernon', 'Skagit'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['JEEP', 'WRANGLER', '2019-2020', 'Poulsbo', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Mount Vernon', 'Skagit'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Lynnwood', 'Snohomish'],
#  ['KIA', 'SPORTAGE', '2023-2024', 'Anacortes', 'Skagit'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Mountlake Terrace', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Spokane', 'Spokane'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Walla Walla', 'Walla Walla'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Walla Walla', 'Walla Walla'],
#  ['AUDI', 'Q5 E', '2023-2024', 'Edmonds', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Everett', 'Snohomish'],
#  ['KIA', 'NIRO', '2017-2018', 'Suquamish', 'Kitsap'],
#  ['KIA', 'SOUL', '2013-2014', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Tumwater', 'Thurston'],
#  ['KIA', 'SORENTO', '2023-2024', 'Lynnwood', 'Snohomish'],
#  ['BMW', 'I3', '2013-2014', 'Lynnwood', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Anacortes', 'Skagit'],
#  ['FIAT', '500', '2015-2016', 'Seattle', 'King'],
#  ['LEXUS', 'NX', '2021-2022', 'Lake Stevens', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Edmonds', 'Snohomish'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Edmonds', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Edmonds', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Edmonds', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Concrete', 'Skagit'],
#  ['AUDI', 'Q5 E', '2019-2020', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Yelm', 'Thurston'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Quincy', 'Grant'],
#  ['AUDI', 'E-TRON', '2017-2018', 'Edmonds', 'Snohomish'],
#  ['AUDI', 'A3', '2017-2018', 'Lacey', 'Thurston'],
#  ['VOLVO', 'XC90', '2015-2016', 'Manson', 'Chelan'],
#  ['KIA', 'EV6', '2021-2022', 'Orondo', 'Douglas'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Seattle', 'King'],
#  ['SUBARU', 'SOLTERRA', '2023-2024', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Renton', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Renton', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Auburn', 'King'],
#  ['NISSAN', 'ARIYA', '2023-2024', 'Kenmore', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2013-2014', 'Seattle', 'King'],
#  ['FORD', 'FUSION', '2015-2016', 'Camas', 'Clark'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Federal Way', 'King'],
#  ['HYUNDAI', 'IONIQ 5', '2021-2022', 'Lake Stevens', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Duvall', 'King'],
#  ['BMW', 'I3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['CHEVROLET', 'SPARK', '2013-2014', 'Bremerton', 'Kitsap'],
#  ['VOLVO', 'XC60', '2021-2022', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Longview', 'Cowlitz'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bothell', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Bothell', 'King'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Kirkland', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2019-2020', 'Port Ludlow', 'Jefferson'],
#  ['TESLA', 'MODEL S', '2019-2020', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Renton', 'King'],
#  ['KIA', 'NIRO', '2019-2020', 'Seattle', 'King'],
#  ['PORSCHE', 'CAYENNE', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Medina', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Burien', 'King'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Shoreline', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Lake Forest Park', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bremerton', 'Kitsap'],
#  ['BMW', 'X5', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bellevue', 'King'],
#  ['FORD', 'F-150', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Yakima', 'Yakima'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Seattle', 'King'],
#  ['KIA', 'EV6', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Bothell', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2023-2024', 'Kirkland', 'King'],
#  ['FORD', 'TRANSIT', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['TOYOTA', 'PRIUS PRIME', '2021-2022', 'Olympia', 'Thurston'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2019-2020', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Port Orchard', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Tukwila', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bothell', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Everett', 'Snohomish'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Kirkland', 'King'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Seattle', 'King'],
#  ['MITSUBISHI', 'OUTLANDER', '2023-2024', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Everett', 'Snohomish'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kent', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Battle Ground', 'Clark'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Bellevue', 'King'],
#  ['TOYOTA', 'BZ4X', '2023-2024', 'Silverdale', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Beaux Arts', 'King'],
#  ['MERCEDES-BENZ', 'EQS-CLASS SEDAN', '2021-2022', 'Edmonds', 'Snohomish'],
#  ['RIVIAN', 'R1T', '2021-2022', 'Battle Ground', 'Clark'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Duvall', 'King'],
#  ['KIA', 'NIRO', '2023-2024', 'Bellevue', 'King'],
#  ['BMW', '745E', '2019-2020', 'Lynnwood', 'Snohomish'],
#  ['HYUNDAI', 'KONA ELECTRIC', '2019-2020', 'Bothell', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['TOYOTA', 'BZ4X', '2021-2022', 'Kelso', 'Cowlitz'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Vancouver', 'Clark'],
#  ['HYUNDAI', 'IONIQ 5', '2021-2022', 'Vancouver', 'Clark'],
#  ['FORD', 'FUSION', '2013-2014', 'Seattle', 'King'],
#  ['FORD', 'F-150', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['TOYOTA', 'RAV4 PRIME', '2023-2024', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Lake Stevens', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bellevue', 'King'],
#  ['JAGUAR', 'I-PACE', '2019-2020', 'Kirkland', 'King'],
#  ['JEEP', 'GRAND CHEROKEE', '2021-2022', 'Auburn', 'King'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Seattle', 'King'],
#  ['AUDI', 'Q4', '2021-2022', 'Redmond', 'King'],
#  ['JEEP', 'GRAND CHEROKEE', '2023-2024', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Kirkland', 'King'],
#  ['BMW', '530E', '2017-2018', 'Bellevue', 'King'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Everett', 'Snohomish'],
#  ['CHEVROLET', 'VOLT', '2013-2014', 'Camas', 'Clark'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Kent', 'King'],
#  ['KIA', 'EV6', '2023-2024', 'Kenmore', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Seattle', 'King'],
#  ['TOYOTA', 'PRIUS PLUG-IN', '2011-2012', 'Seattle', 'King'],
#  ['KIA', 'EV6', '2023-2024', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kent', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Selah', 'Yakima'],
#  ['CHEVROLET', 'VOLT', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kent', 'King'],
#  ['KIA', 'EV9', '2023-2024', 'Sammamish', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2021-2022', 'Auburn', 'King'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Sammamish', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bellevue', 'King'],
#  ['HYUNDAI', 'IONIQ 5', '2021-2022', 'Bothell', 'King'],
#  ['TESLA', 'MODEL S', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2021-2022', 'Silverdale', 'Kitsap'],
#  ['PORSCHE', 'TAYCAN', '2023-2024', 'Sammamish', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Kirkland', 'King'],
#  ['CHEVROLET', 'VOLT', '2013-2014', 'Renton', 'King'],
#  ['FORD', 'C-MAX', '2011-2012', 'Port Townsend', 'Jefferson'],
#  ['BMW', 'X5', '2021-2022', 'Bellevue', 'King'],
#  ['VOLVO', 'V60', '2023-2024', 'Seattle', 'King'],
#  ['AUDI', 'E-TRON', '2019-2020', 'Bothell', 'King'],
#  ['KIA', 'EV6', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['TOYOTA', 'PRIUS PLUG-IN', '2011-2012', 'Lacey', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Burien', 'King'],
#  ['MITSUBISHI', 'OUTLANDER', '2021-2022', 'Castle Rock', 'Cowlitz'],
#  ['FORD', 'MUSTANG MACH-E', '2021-2022', 'Burien', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Newcastle', 'King'],
#  ['BMW', 'IX', '2023-2024', 'Rainier', 'Thurston'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['KIA', 'NIRO', '2019-2020', 'Seattle', 'King'],
#  ['AUDI', 'SQ8', '2023-2024', 'Mukilteo', 'Snohomish'],
#  ['BMW', 'I3', '2013-2014', 'Brush Prairie', 'Clark'],
#  ['NISSAN', 'LEAF', '2015-2016', 'North Bend', 'King'],
#  ['FORD', 'FUSION', '2013-2014', 'Vancouver', 'Clark'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Kent', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bremerton', 'Kitsap'],
#  ['KIA', 'NIRO', '2017-2018', 'Redmond', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bothell', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Vancouver', 'Clark'],
#  ['TOYOTA', 'BZ4X', '2023-2024', 'Seattle', 'King'],
#  ['BMW', '330E', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bremerton', 'Kitsap'],
#  ['KIA', 'SOUL', '2013-2014', 'Seattle', 'King'],
#  ['CHEVROLET', 'VOLT', '2013-2014', 'Port Townsend', 'Jefferson'],
#  ['NISSAN', 'LEAF', '2019-2020', 'Seattle', 'King'],
#  ['HYUNDAI', 'IONIQ 5', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Sammamish', 'King'],
#  ['MERCEDES-BENZ', 'EQS-CLASS SUV', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Seattle', 'King'],
#  ['HYUNDAI', 'IONIQ 5', '2021-2022', 'Port Orchard', 'Kitsap'],
#  ['LEXUS', 'NX', '2023-2024', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seatac', 'King'],
#  ['KIA', 'SPORTAGE', '2021-2022', 'Port Orchard', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Sammamish', 'King'],
#  ['NISSAN', 'ARIYA', '2021-2022', 'Auburn', 'King'],
#  ['LEXUS', 'RZ', '2021-2022', 'Kent', 'King'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bellevue', 'King'],
#  ['KIA', 'EV9', '2023-2024', 'Bothell', 'King'],
#  ['KIA', 'EV6', '2021-2022', 'Zillah', 'Yakima'],
#  ['KIA', 'NIRO', '2021-2022', 'Shoreline', 'King'],
#  ['BMW', 'I4', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bothell', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2015-2016', 'Seattle', 'King'],
#  ['TOYOTA', 'PRIUS PLUG-IN', '2011-2012', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Newcastle', 'King'],
#  ['AUDI', 'Q5 E', '2023-2024', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Bellevue', 'King'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Port Townsend', 'Jefferson'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seabeck', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Newcastle', 'King'],
#  ['HONDA', 'CLARITY', '2017-2018', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Longview', 'Cowlitz'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Kent', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['BMW', 'I3', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['VOLVO', 'XC40', '2023-2024', 'Bellevue', 'King'],
#  ['HONDA', 'CLARITY', '2017-2018', 'Ridgefield', 'Clark'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Camas', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Newcastle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['JEEP', 'WRANGLER', '2019-2020', 'Nine Mile Falls', 'Stevens'],
#  ['VOLVO', 'XC40', '2021-2022', 'Woodinville', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Lake Stevens', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2021-2022', 'Seattle', 'King'],
#  ['MERCEDES-BENZ', 'EQB-CLASS', '2023-2024', 'Bothell', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Shoreline', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Sammamish', 'King'],
#  ['VOLVO', 'XC90', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Olympia', 'Thurston'],
#  ['FORD', 'FUSION', '2017-2018', 'Battle Ground', 'Clark'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Newcastle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kirkland', 'King'],
#  ['BMW', 'X5', '2017-2018', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['HYUNDAI', 'TUCSON', '2023-2024', 'Bothell', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Kirkland', 'King'],
#  ['JEEP', 'WRANGLER', '2019-2020', 'Bellevue', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2015-2016', 'Burien', 'King'],
#  ['BMW', 'I4', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['FORD', 'MUSTANG MACH-E', '2023-2024', 'Renton', 'King'],
#  ['JEEP', 'WRANGLER', '2019-2020', 'Auburn', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Vancouver', 'Clark'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Shoreline', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2019-2020', 'Renton', 'King'],
#  ['CHEVROLET', 'EQUINOX EV', '2023-2024', 'Lake Stevens', 'Snohomish'],
#  ['PORSCHE', 'TAYCAN', '2021-2022', 'Redmond', 'King'],
#  ['HYUNDAI', 'KONA ELECTRIC', '2019-2020', 'Seattle', 'King'],
#  ['CHEVROLET', 'VOLT', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Mabton', 'Yakima'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['HONDA', 'PROLOGUE', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Seattle', 'King'],
#  ['BMW', 'I5', '2023-2024', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kirkland', 'King'],
#  ['MINI', 'HARDTOP', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Kirkland', 'King'],
#  ['GMC', 'HUMMER EV PICKUP', '2023-2024', 'Kirkland', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2021-2022', 'Poulsbo', 'Kitsap'],
#  ['TESLA', 'MODEL X', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Kirkland', 'King'],
#  ['PORSCHE', 'TAYCAN', '2021-2022', 'Burien', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Burien', 'King'],
#  ['NISSAN', 'LEAF', '2019-2020', 'Bothell', 'Snohomish'],
#  ['TOYOTA', 'PRIUS PRIME', '2017-2018', 'Poulsbo', 'Kitsap'],
#  ['TOYOTA', 'PRIUS PRIME', '2015-2016', 'Burien', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Kirkland', 'King'],
#  ['LUCID', 'AIR', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['FORD', 'F-150', '2023-2024', 'Olympia', 'Thurston'],
#  ['HYUNDAI', 'IONIQ 5', '2021-2022', 'Woodinville', 'King'],
#  ['VOLVO', 'XC90', '2019-2020', 'Bellevue', 'King'],
#  ['KIA', 'EV9', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'North Bend', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['RIVIAN', 'R1T', '2023-2024', 'Shoreline', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Renton', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2015-2016', 'Seattle', 'King'],
#  ['POLESTAR', 'PS2', '2023-2024', 'Seattle', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2021-2022', 'Bothell', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bellevue', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2019-2020', 'Enumclaw', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Woodinville', 'King'],
#  ['FORD', 'F-150', '2021-2022', 'Kent', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'La Center', 'Clark'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Seabeck', 'Kitsap'],
#  ['FORD', 'FOCUS', '2013-2014', 'Kent', 'King'],
#  ['BMW', 'X5', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Yelm', 'Thurston'],
#  ['HYUNDAI', 'IONIQ', '2017-2018', 'Selah', 'Yakima'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Sammamish', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2023-2024', 'Kent', 'King'],
#  ['TESLA', 'MODEL S', '2019-2020', 'Seattle', 'King'],
#  ['CHEVROLET', 'BLAZER EV', '2023-2024', 'Lake Stevens', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['KIA', 'EV9', '2023-2024', 'Redmond', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2019-2020', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['TOYOTA', 'BZ4X', '2023-2024', 'Vancouver', 'Clark'],
#  ['CHRYSLER', 'PACIFICA', '2021-2022', 'Selah', 'Yakima'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Battle Ground', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Renton', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Vancouver', 'Clark'],
#  ['CHEVROLET', 'BOLT EV', '2015-2016', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Renton', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL X', '2023-2024', 'Bellevue', 'King'],
#  ['BMW', 'X5', '2019-2020', 'Seattle', 'King'],
#  ['KIA', 'SORENTO', '2021-2022', 'Shoreline', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2019-2020', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Issaquah', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2023-2024', 'Port Orchard', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Kirkland', 'King'],
#  ['FORD', 'F-150', '2021-2022', 'Brinnon', 'Jefferson'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Kirkland', 'King'],
#  ['CADILLAC', 'LYRIQ', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Port Townsend', 'Jefferson'],
#  ['NISSAN', 'ARIYA', '2021-2022', 'Everett', 'Snohomish'],
#  ['VOLVO', 'XC90', '2015-2016', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Newcastle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Kirkland', 'King'],
#  ['VOLVO', 'XC90', '2023-2024', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['CHEVROLET', 'VOLT', '2017-2018', 'Bellevue', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2017-2018', 'Seattle', 'King'],
#  ['CHRYSLER', 'PACIFICA', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['VOLVO', 'XC90', '2021-2022', 'Auburn', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Battle Ground', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Woodinville', 'King'],
#  ['KIA', 'SOUL', '2015-2016', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bellevue', 'King'],
#  ['BMW', 'IX', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Seattle', 'King'],
#  ['HYUNDAI', 'IONIQ 5', '2023-2024', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Redmond', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Redmond', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2021-2022', 'Washougal', 'Clark'],
#  ['CHEVROLET', 'BOLT EV', '2021-2022', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Bellevue', 'King'],
#  ['MITSUBISHI', 'I-MIEV', '2011-2012', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bellevue', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Silverdale', 'Kitsap'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Redmond', 'King'],
#  ['BMW', 'I4', '2021-2022', 'Seattle', 'King'],
#  ['VOLVO', 'XC60', '2021-2022', 'Seattle', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2019-2020', 'Seattle', 'King'],
#  ['BMW', 'IX', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['RIVIAN', 'R1T', '2023-2024', 'Bainbridge Island', 'Kitsap'],
#  ['AUDI', 'A3', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Kirkland', 'King'],
#  ['KIA', 'SORENTO', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bothell', 'King'],
#  ['RIVIAN', 'R1T', '2021-2022', 'Bellevue', 'King'],
#  ['MERCEDES-BENZ', 'GLC-CLASS', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Seattle', 'King'],
#  ['AUDI', 'Q8', '2023-2024', 'Seattle', 'King'],
#  ['FORD', 'TRANSIT', '2021-2022', 'Tumwater', 'Thurston'],
#  ['KIA', 'EV6', '2023-2024', 'Bellevue', 'King'],
#  ['AUDI', 'E-TRON', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Vancouver', 'Clark'],
#  ['RIVIAN', 'R1S', '2021-2022', 'Seattle', 'King'],
#  ['CADILLAC', 'LYRIQ', '2023-2024', 'Bellevue', 'King'],
#  ['KIA', 'NIRO', '2023-2024', 'Shoreline', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['SMART', 'FORTWO ELECTRIC DRIVE', '2013-2014', 'Seattle', 'King'],
#  ['JEEP', 'WRANGLER', '2021-2022', 'Lake Stevens', 'Snohomish'],
#  ['RIVIAN', 'R1S', '2021-2022', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Auburn', 'King'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Port Ludlow', 'Jefferson'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Renton', 'King'],
#  ['FORD', 'F-150', '2023-2024', 'Issaquah', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Seattle', 'King'],
#  ['AUDI', 'Q5 E', '2019-2020', 'Bellevue', 'King'],
#  ['CHEVROLET', 'VOLT', '2011-2012', 'Yakima', 'Yakima'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Renton', 'King'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Vancouver', 'Clark'],
#  ['JAGUAR', 'I-PACE', '2019-2020', 'Issaquah', 'King'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Seattle', 'King'],
#  ['KIA', 'EV6', '2023-2024', 'Yakima', 'Yakima'],
#  ['KIA', 'EV9', '2023-2024', 'Burien', 'King'],
#  ['LINCOLN', 'AVIATOR', '2019-2020', 'Port Orchard', 'Kitsap'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['BMW', 'I4', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Seattle', 'King'],
#  ['HONDA', 'PROLOGUE', '2023-2024', 'Renton', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Redmond', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Olympia', 'Thurston'],
#  ['VOLKSWAGEN', 'ID.4', '2019-2020', 'Shoreline', 'King'],
#  ['VOLVO', 'XC90', '2019-2020', 'Bellevue', 'King'],
#  ['RIVIAN', 'R1S', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Burien', 'King'],
#  ['BMW', 'I4', '2023-2024', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Vancouver', 'Clark'],
#  ['LINCOLN', 'AVIATOR', '2019-2020', 'Burien', 'King'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bellevue', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2019-2020', 'Bellevue', 'King'],
#  ['KIA', 'EV6', '2023-2024', 'Seattle', 'King'],
#  ['CHRYSLER', 'PACIFICA', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2015-2016', 'Shoreline', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Issaquah', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Renton', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2023-2024', 'Seattle', 'King'],
#  ['VOLVO', 'S90', '2017-2018', 'Vancouver', 'Clark'],
#  ['VOLVO', 'XC60', '2023-2024', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2015-2016', 'Shoreline', 'King'],
#  ['JEEP', 'WRANGLER', '2021-2022', 'La Center', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Vancouver', 'Clark'],
#  ['FORD', 'ESCAPE', '2021-2022', 'Kent', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Mill Creek', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Camas', 'Clark'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bellevue', 'King'],
#  ['SUBARU', 'SOLTERRA', '2023-2024', 'Bellevue', 'King'],
#  ['AUDI', 'E-TRON GT', '2021-2022', 'Bellevue', 'King'],
#  ['RIVIAN', 'R1S', '2021-2022', 'Bothell', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['FORD', 'F-150', '2021-2022', 'Port Ludlow', 'Jefferson'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Renton', 'King'],
#  ['FORD', 'TRANSIT', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Rainier', 'Thurston'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bellevue', 'King'],
#  ['FORD', 'FUSION', '2015-2016', 'Kirkland', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kent', 'King'],
#  ['CHEVROLET', 'BLAZER EV', '2023-2024', 'Vancouver', 'Clark'],
#  ['VOLVO', 'XC60', '2023-2024', 'Issaquah', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['JEEP', 'WRANGLER', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Shoreline', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2019-2020', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2021-2022', 'Lake Forest Park', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Sammamish', 'King'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['LUCID', 'AIR', '2021-2022', 'Seattle', 'King'],
#  ['NISSAN', 'ARIYA', '2021-2022', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Lake Stevens', 'Snohomish'],
#  ['CHEVROLET', 'VOLT', '2017-2018', 'Yelm', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Edmonds', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Redmond', 'King'],
#  ['MERCEDES-BENZ', 'EQS-CLASS SEDAN', '2021-2022', 'Kirkland', 'King'],
#  ['KIA', 'SPORTAGE', '2023-2024', 'Seattle', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Port Townsend', 'Jefferson'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bellevue', 'King'],
#  ['FORD', 'C-MAX', '2015-2016', 'Bellevue', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Vancouver', 'Clark'],
#  ['BMW', 'I3', '2013-2014', 'Seattle', 'King'],
#  ['AUDI', 'Q5 E', '2023-2024', 'Kirkland', 'King'],
#  ['VOLKSWAGEN', 'E-GOLF', '2017-2018', 'Bainbridge Island', 'Kitsap'],
#  ['FORD', 'FUSION', '2013-2014', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Issaquah', 'King'],
#  ['SUBARU', 'SOLTERRA', '2023-2024', 'Kirkland', 'King'],
#  ['HYUNDAI', 'KONA', '2019-2020', 'Port Townsend', 'Jefferson'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Auburn', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['JEEP', 'GRAND CHEROKEE', '2021-2022', 'La Center', 'Clark'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Vancouver', 'Clark'],
#  ['KIA', 'SPORTAGE', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Renton', 'King'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Renton', 'King'],
#  ['KIA', 'NIRO', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kent', 'King'],
#  ['NISSAN', 'LEAF', '2009-2010', 'Seattle', 'King'],
#  ['FORD', 'C-MAX', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2021-2022', 'Redmond', 'King'],
#  ['HYUNDAI', 'KONA ELECTRIC', '2021-2022', 'Kirkland', 'King'],
#  ['HYUNDAI', 'IONIQ 6', '2023-2024', 'Everett', 'Snohomish'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Washougal', 'Clark'],
#  ['BMW', 'I5', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Woodinville', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bothell', 'Snohomish'],
#  ['MERCEDES-BENZ', 'EQB-CLASS', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Vancouver', 'Clark'],
#  ['AUDI', 'Q5 E', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['KIA', 'NIRO', '2021-2022', 'Burien', 'King'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Kirkland', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Kirkland', 'King'],
#  ['FORD', 'C-MAX', '2015-2016', 'Port Townsend', 'Jefferson'],
#  ['FORD', 'MUSTANG MACH-E', '2023-2024', 'Bainbridge Island', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2009-2010', 'Yakima', 'Yakima'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2021-2022', 'Issaquah', 'King'],
#  ['MERCEDES-BENZ', 'C-CLASS', '2017-2018', 'Bainbridge Island', 'Kitsap'],
#  ['FORD', 'C-MAX', '2013-2014', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Rainier', 'Thurston'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['BMW', 'I4', '2023-2024', 'Bellevue', 'King'],
#  ['BMW', 'X3', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Lake Forest Park', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Vancouver', 'Clark'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Vancouver', 'Clark'],
#  ['TOYOTA', 'BZ4X', '2023-2024', 'Newcastle', 'King'],
#  ['FORD', 'F-150', '2021-2022', 'Seattle', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL X', '2017-2018', 'Kenmore', 'King'],
#  ['MITSUBISHI', 'OUTLANDER', '2019-2020', 'Seattle', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2021-2022', 'Olympia', 'Thurston'],
#  ['BMW', 'I4', '2021-2022', 'Renton', 'King'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Sammamish', 'King'],
#  ['SUBARU', 'SOLTERRA', '2021-2022', 'Bellevue', 'King'],
#  ['CHRYSLER', 'PACIFICA', '2017-2018', 'Vancouver', 'Clark'],
#  ['KIA', 'SOUL', '2015-2016', 'Bothell', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Tukwila', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Monroe', 'Snohomish'],
#  ['TOYOTA', 'PRIUS PRIME', '2017-2018', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Milton', 'King'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Woodinville', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL X', '2023-2024', 'Kirkland', 'King'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Rochester', 'Thurston'],
#  ['RIVIAN', 'R1S', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Kirkland', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2019-2020', 'Seattle', 'King'],
#  ['CADILLAC', 'LYRIQ', '2023-2024', 'Olympia', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Lake Stevens', 'Snohomish'],
#  ['VOLVO', 'XC60', '2021-2022', 'Seattle', 'King'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'North Bend', 'King'],
#  ['VOLVO', 'XC60', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['HYUNDAI', 'IONIQ 5', '2023-2024', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Auburn', 'King'],
#  ['NISSAN', 'ARIYA', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2019-2020', 'Auburn', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2019-2020', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Bellevue', 'King'],
#  ['FIAT', '500', '2013-2014', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['MERCEDES-BENZ', 'EQB-CLASS', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Everett', 'Snohomish'],
#  ['TESLA', 'MODEL S', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Vancouver', 'Clark'],
#  ['CHRYSLER', 'PACIFICA', '2019-2020', 'Port Orchard', 'Kitsap'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Sammamish', 'King'],
#  ['RIVIAN', 'R1S', '2023-2024', 'Redmond', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2015-2016', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bremerton', 'Kitsap'],
#  ['VOLVO', 'XC60', '2021-2022', 'Federal Way', 'King'],
#  ['BMW', 'IX', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['FORD', 'C-MAX', '2013-2014', 'Port Orchard', 'Kitsap'],
#  ['BMW', 'XM', '2023-2024', 'Tukwila', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2015-2016', 'Redmond', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Vancouver', 'Clark'],
#  ['VOLKSWAGEN', 'E-GOLF', '2015-2016', 'Seattle', 'King'],
#  ['CHRYSLER', 'PACIFICA', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Redmond', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Bellevue', 'King'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Woodinville', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2021-2022', 'Vancouver', 'Clark'],
#  ['VOLVO', 'XC90', '2019-2020', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bellevue', 'King'],
#  ['BMW', 'I3', '2013-2014', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL X', '2021-2022', 'Newcastle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Port Orchard', 'Kitsap'],
#  ['MAZDA', 'CX-90', '2023-2024', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2019-2020', 'Bellevue', 'King'],
#  ['CHEVROLET', 'VOLT', '2015-2016', 'Bothell', 'Snohomish'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Vancouver', 'Clark'],
#  ['HYUNDAI', 'IONIQ 5', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kent', 'King'],
#  ['BMW', '530E', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Renton', 'King'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL S', '2019-2020', 'Seattle', 'King'],
#  ['VOLVO', 'XC90', '2023-2024', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Kirkland', 'King'],
#  ['BMW', 'I4', '2023-2024', 'Bellevue', 'King'],
#  ['NISSAN', 'LEAF', '2013-2014', 'Bellevue', 'King'],
#  ['FORD', 'F-150', '2021-2022', 'Yelm', 'Thurston'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Seattle', 'King'],
#  ['LAND ROVER', 'RANGE ROVER SPORT', '2023-2024', 'Sammamish', 'King'],
#  ['RIVIAN', 'R1T', '2021-2022', 'Shoreline', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bellevue', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2021-2022', 'Woodinville', 'King'],
#  ['CHEVROLET', 'VOLT', '2017-2018', 'Seattle', 'King'],
#  ['TOYOTA', 'PRIUS PRIME', '2015-2016', 'Auburn', 'King'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bellevue', 'King'],
#  ['TOYOTA', 'BZ4X', '2023-2024', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Vancouver', 'Clark'],
#  ['NISSAN', 'LEAF', '2011-2012', 'Federal Way', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2019-2020', 'Seattle', 'King'],
#  ['KIA', 'NIRO', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Issaquah', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Kent', 'King'],
#  ['NISSAN', 'LEAF', '2015-2016', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Seattle', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2021-2022', 'Auburn', 'King'],
#  ['TESLA', 'MODEL X', '2019-2020', 'Kirkland', 'King'],
#  ['BMW', 'I3', '2013-2014', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Newcastle', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Sammamish', 'King'],
#  ['RIVIAN', 'R1S', '2021-2022', 'Snohomish', 'Snohomish'],
#  ['JEEP', 'WRANGLER', '2021-2022', 'Kirkland', 'King'],
#  ['AUDI', 'E-TRON', '2017-2018', 'Port Orchard', 'Kitsap'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Vancouver', 'Clark'],
#  ['MITSUBISHI', 'OUTLANDER', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2023-2024', 'Bellevue', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Redmond', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Bellevue', 'King'],
#  ['VOLVO', 'XC90', '2015-2016', 'Bainbridge Island', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['JEEP', 'WRANGLER', '2023-2024', 'Vancouver', 'Clark'],
#  ['BMW', 'I3', '2017-2018', 'Burien', 'King'],
#  ['VOLVO', 'XC40', '2019-2020', 'Bainbridge Island', 'Kitsap'],
#  ['POLESTAR', 'PS2', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Vancouver', 'Clark'],
#  ['HYUNDAI', 'TUCSON', '2023-2024', 'Seattle', 'King'],
#  ['BMW', 'X3', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Federal Way', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Selah', 'Yakima'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Renton', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Seattle', 'King'],
#  ['BMW', 'X5', '2019-2020', 'Redmond', 'King'],
#  ['TOYOTA', 'RAV4 PRIME', '2021-2022', 'Seattle', 'King'],
#  ['CHEVROLET', 'EQUINOX EV', '2023-2024', 'Sammamish', 'King'],
#  ['FORD', 'FUSION', '2019-2020', 'Ariel', 'Cowlitz'],
#  ['RIVIAN', 'R1T', '2021-2022', 'Bellevue', 'King'],
#  ['FIAT', '500', '2015-2016', 'Yakima', 'Yakima'],
#  ['AUDI', 'E-TRON', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Redmond', 'King'],
#  ['VOLVO', 'XC40', '2021-2022', 'Vancouver', 'Clark'],
#  ['CHEVROLET', 'BOLT EV', '2021-2022', 'Camas', 'Clark'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Bellevue', 'King'],
#  ['AUDI', 'E-TRON', '2019-2020', 'Redmond', 'King'],
#  ['PORSCHE', 'TAYCAN', '2019-2020', 'Vancouver', 'Clark'],
#  ['TOYOTA', 'PRIUS PLUG-IN', '2013-2014', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Des Moines', 'King'],
#  ['TESLA', 'MODEL S', '2013-2014', 'Seattle', 'King'],
#  ['JEEP', 'GRAND CHEROKEE', '2023-2024', 'Port Orchard', 'Kitsap'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Renton', 'King'],
#  ['TESLA', 'MODEL Y', '2023-2024', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Vancouver', 'Clark'],
#  ['NISSAN', 'ARIYA', '2021-2022', 'Tukwila', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL X', '2021-2022', 'Redmond', 'King'],
#  ['CHEVROLET', 'BOLT EUV', '2021-2022', 'Kirkland', 'King'],
#  ['BMW', 'I3', '2015-2016', 'Kent', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Vancouver', 'Clark'],
#  ['MINI', 'HARDTOP', '2021-2022', 'Kirkland', 'King'],
#  ['NISSAN', 'LEAF', '2021-2022', 'Bellevue', 'King'],
#  ['NISSAN', 'LEAF', '2009-2010', 'Vancouver', 'Clark'],
#  ['TESLA', 'MODEL Y', '2019-2020', 'Newcastle', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Seattle', 'King'],
#  ['KIA', 'EV6', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Bellevue', 'King'],
#  ['CHEVROLET', 'EQUINOX EV', '2023-2024', 'Poulsbo', 'Kitsap'],
#  ['FORD', 'TRANSIT', '2021-2022', 'Tukwila', 'King'],
#  ['TESLA', 'MODEL 3', '2023-2024', 'Kent', 'King'],
#  ['KIA', 'EV9', '2023-2024', 'Camas', 'Clark'],
#  ['VOLKSWAGEN', 'ID.4', '2021-2022', 'Bellevue', 'King'],
#  ['VOLKSWAGEN', 'ID.4', '2019-2020', 'Olympia', 'Thurston'],
#  ['NISSAN', 'LEAF', '2017-2018', 'Seattle', 'King'],
#  ['VOLVO', 'C40', '2021-2022', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Arlington', 'Snohomish'],
#  ['KIA', 'EV6', '2021-2022', 'Vancouver', 'Clark'],
#  ['BMW', 'IX', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Issaquah', 'King'],
#  ['CADILLAC', 'LYRIQ', '2023-2024', 'Federal Way', 'King'],
#  ['TESLA', 'MODEL 3', '2017-2018', 'Sammamish', 'King'],
#  ['CHEVROLET', 'VOLT', '2017-2018', 'Seattle', 'King'],
#  ['KIA', 'NIRO', '2019-2020', 'Seattle', 'King'],
#  ['JEEP', 'WRANGLER', '2023-2024', 'Battle Ground', 'Clark'],
#  ['TOYOTA', 'PRIUS PRIME', '2021-2022', 'Vancouver', 'Clark'],
#  ['CHEVROLET', 'BOLT EV', '2017-2018', 'Kirkland', 'King'],
#  ['LUCID', 'AIR', '2023-2024', 'Redmond', 'King'],
#  ['TESLA', 'MODEL Y', '2021-2022', 'Kirkland', 'King'],
#  ['CHEVROLET', 'BOLT EV', '2021-2022', 'Seattle', 'King'],
#  ['TESLA', 'MODEL S', '2011-2012', 'Kent', 'King'],
#  ['VOLVO', 'XC40', '2021-2022', 'Kirkland', 'King'],
#  ['TESLA', 'MODEL 3', '2019-2020', 'Redmond', 'King'],
#  ['HYUNDAI', 'IONIQ 6', '2023-2024', 'Seatac', 'King'],
#  ['RIVIAN', 'R1S', '2021-2022', 'Seattle', 'King'],
#  ['FORD', 'MUSTANG MACH-E', '2019-2020', 'Seattle', 'King'],
#  ['CHEVROLET', 'BLAZER EV', '2023-2024', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL S', '2015-2016', 'Bellevue', 'King'],
#  ['TESLA', 'MODEL 3', '2021-2022', 'Bainbridge Island', 'Kitsap'],
#  ['KIA', 'NIRO', '2017-2018', 'Sammamish', 'King'],
#  ...]

# %% [markdown]
# ###**a) Market Basket Analysis 1: Mining the relationship between car brand and models.**

# %%
df_city_model = df_filtered[['Make', 'Model']].copy()
df_transactions_make_model = df_city_model.astype(str).values.tolist()
df_transactions_make_model
# Out:
# [['JEEP', 'WRANGLER'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['JEEP', 'WRANGLER'],
#  ['BMW', '530E'],
#  ['TESLA', 'MODEL X'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['LEXUS', 'RZ'],
#  ['KIA', 'EV6'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL S'],
#  ['POLESTAR', 'PS2'],
#  ['TESLA', 'MODEL S'],
#  ['HYUNDAI', 'SANTA FE'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['JEEP', 'WRANGLER'],
#  ['BMW', '330E'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['RIVIAN', 'R1T'],
#  ['VOLVO', 'XC60'],
#  ['BMW', 'X5'],
#  ['FIAT', '500'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['MAZDA', 'CX-90'],
#  ['MAZDA', 'CX-90'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL X'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['RIVIAN', 'R1S'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'E-TRON'],
#  ['LEXUS', 'RX'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['BMW', 'I3'],
#  ['BMW', 'IX'],
#  ['JEEP', 'WRANGLER'],
#  ['BMW', 'X5'],
#  ['KIA', 'NIRO'],
#  ['NISSAN', 'LEAF'],
#  ['KIA', 'NIRO'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'EV6'],
#  ['RIVIAN', 'R1S'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL S'],
#  ['HYUNDAI', 'IONIQ'],
#  ['TESLA', 'MODEL S'],
#  ['KIA', 'SOUL'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'F-150'],
#  ['BMW', '330E'],
#  ['TESLA', 'MODEL S'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'Q5 E'],
#  ['JEEP', 'WRANGLER'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLVO', 'XC90'],
#  ['KIA', 'SORENTO'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['NISSAN', 'LEAF'],
#  ['JEEP', 'GRAND CHEROKEE'],
#  ['JEEP', 'WRANGLER'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL X'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['KIA', 'SORENTO'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['FIAT', '500'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'X5'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'X5'],
#  ['BMW', '530E'],
#  ['TESLA', 'MODEL S'],
#  ['MAZDA', 'CX-90'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'SOUL'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['KIA', 'SOUL'],
#  ['MERCEDES-BENZ', 'GLC-CLASS'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'SORENTO'],
#  ['AUDI', 'A3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['MAZDA', 'CX-70'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['FIAT', '500'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['MAZDA', 'CX-90'],
#  ['BMW', 'I3'],
#  ['NISSAN', 'LEAF'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL S'],
#  ['HONDA', 'CLARITY'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'C-MAX'],
#  ['MITSUBISHI', 'OUTLANDER'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TOYOTA', 'PRIUS PLUG-IN'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['JEEP', 'WRANGLER'],
#  ['AUDI', 'Q5'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL S'],
#  ['LEXUS', 'NX'],
#  ['NISSAN', 'LEAF'],
#  ['FORD', 'C-MAX'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['TESLA', 'MODEL X'],
#  ['NISSAN', 'LEAF'],
#  ['BMW', 'X5'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'Q5 E'],
#  ['KIA', 'SOUL'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL 3'],
#  ['JEEP', 'WRANGLER'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'SPORTAGE'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'Q5 E'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'NIRO'],
#  ['KIA', 'SOUL'],
#  ['NISSAN', 'LEAF'],
#  ['KIA', 'SORENTO'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL Y'],
#  ['FIAT', '500'],
#  ['LEXUS', 'NX'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['AUDI', 'Q5 E'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'E-TRON'],
#  ['AUDI', 'A3'],
#  ['VOLVO', 'XC90'],
#  ['KIA', 'EV6'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['SUBARU', 'SOLTERRA'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'ARIYA'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['FORD', 'FUSION'],
#  ['TESLA', 'MODEL 3'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['NISSAN', 'LEAF'],
#  ['BMW', 'I3'],
#  ['CHEVROLET', 'SPARK'],
#  ['VOLVO', 'XC60'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'NIRO'],
#  ['PORSCHE', 'CAYENNE'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['BMW', 'X5'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'F-150'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['KIA', 'EV6'],
#  ['TESLA', 'MODEL S'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['FORD', 'TRANSIT'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['MITSUBISHI', 'OUTLANDER'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL S'],
#  ['TOYOTA', 'BZ4X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['MERCEDES-BENZ', 'EQS-CLASS SEDAN'],
#  ['RIVIAN', 'R1T'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'NIRO'],
#  ['BMW', '745E'],
#  ['HYUNDAI', 'KONA ELECTRIC'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'BZ4X'],
#  ['TESLA', 'MODEL 3'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['FORD', 'FUSION'],
#  ['FORD', 'F-150'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['JAGUAR', 'I-PACE'],
#  ['JEEP', 'GRAND CHEROKEE'],
#  ['TESLA', 'MODEL X'],
#  ['AUDI', 'Q4'],
#  ['JEEP', 'GRAND CHEROKEE'],
#  ['TESLA', 'MODEL S'],
#  ['BMW', '530E'],
#  ['CHEVROLET', 'VOLT'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'EV6'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'PRIUS PLUG-IN'],
#  ['KIA', 'EV6'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'EV9'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL S'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['PORSCHE', 'TAYCAN'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'VOLT'],
#  ['FORD', 'C-MAX'],
#  ['BMW', 'X5'],
#  ['VOLVO', 'V60'],
#  ['AUDI', 'E-TRON'],
#  ['KIA', 'EV6'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'PRIUS PLUG-IN'],
#  ['TESLA', 'MODEL 3'],
#  ['MITSUBISHI', 'OUTLANDER'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['BMW', 'IX'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'NIRO'],
#  ['AUDI', 'SQ8'],
#  ['BMW', 'I3'],
#  ['NISSAN', 'LEAF'],
#  ['FORD', 'FUSION'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'BZ4X'],
#  ['BMW', '330E'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'SOUL'],
#  ['CHEVROLET', 'VOLT'],
#  ['NISSAN', 'LEAF'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['TESLA', 'MODEL S'],
#  ['MERCEDES-BENZ', 'EQS-CLASS SUV'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['LEXUS', 'NX'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'SPORTAGE'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'ARIYA'],
#  ['LEXUS', 'RZ'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'EV9'],
#  ['KIA', 'EV6'],
#  ['KIA', 'NIRO'],
#  ['BMW', 'I4'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TOYOTA', 'PRIUS PLUG-IN'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'Q5 E'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['HONDA', 'CLARITY'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL 3'],
#  ['MAZDA', 'CX-90'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLVO', 'XC40'],
#  ['HONDA', 'CLARITY'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['JEEP', 'WRANGLER'],
#  ['VOLVO', 'XC40'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['MERCEDES-BENZ', 'EQB-CLASS'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'FUSION'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'X5'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['HYUNDAI', 'TUCSON'],
#  ['TESLA', 'MODEL 3'],
#  ['JEEP', 'WRANGLER'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['BMW', 'I4'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['JEEP', 'WRANGLER'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['CHEVROLET', 'VOLT'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['CHEVROLET', 'EQUINOX EV'],
#  ['PORSCHE', 'TAYCAN'],
#  ['HYUNDAI', 'KONA ELECTRIC'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['HONDA', 'PROLOGUE'],
#  ['TESLA', 'MODEL X'],
#  ['BMW', 'I5'],
#  ['TESLA', 'MODEL 3'],
#  ['MINI', 'HARDTOP'],
#  ['TESLA', 'MODEL Y'],
#  ['GMC', 'HUMMER EV PICKUP'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL S'],
#  ['PORSCHE', 'TAYCAN'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['LUCID', 'AIR'],
#  ['FORD', 'F-150'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['VOLVO', 'XC90'],
#  ['KIA', 'EV9'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['RIVIAN', 'R1T'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['POLESTAR', 'PS2'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'F-150'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'FOCUS'],
#  ['BMW', 'X5'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL Y'],
#  ['HYUNDAI', 'IONIQ'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'BLAZER EV'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'EV9'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'BZ4X'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['BMW', 'X5'],
#  ['KIA', 'SORENTO'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'F-150'],
#  ['TESLA', 'MODEL Y'],
#  ['CADILLAC', 'LYRIQ'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'ARIYA'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'LEAF'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'VOLT'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'SOUL'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'IX'],
#  ['TESLA', 'MODEL S'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['NISSAN', 'LEAF'],
#  ['MITSUBISHI', 'I-MIEV'],
#  ['NISSAN', 'LEAF'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'I4'],
#  ['VOLVO', 'XC60'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['BMW', 'IX'],
#  ['TESLA', 'MODEL Y'],
#  ['RIVIAN', 'R1T'],
#  ['AUDI', 'A3'],
#  ['TESLA', 'MODEL X'],
#  ['KIA', 'SORENTO'],
#  ['TESLA', 'MODEL 3'],
#  ['RIVIAN', 'R1T'],
#  ['MERCEDES-BENZ', 'GLC-CLASS'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL Y'],
#  ['AUDI', 'Q8'],
#  ['FORD', 'TRANSIT'],
#  ['KIA', 'EV6'],
#  ['AUDI', 'E-TRON'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['RIVIAN', 'R1S'],
#  ['CADILLAC', 'LYRIQ'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL Y'],
#  ['SMART', 'FORTWO ELECTRIC DRIVE'],
#  ['JEEP', 'WRANGLER'],
#  ['RIVIAN', 'R1S'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'F-150'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['AUDI', 'Q5 E'],
#  ['CHEVROLET', 'VOLT'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL X'],
#  ['JAGUAR', 'I-PACE'],
#  ['NISSAN', 'LEAF'],
#  ['KIA', 'EV6'],
#  ['KIA', 'EV9'],
#  ['LINCOLN', 'AVIATOR'],
#  ['MAZDA', 'CX-90'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['BMW', 'I4'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['HONDA', 'PROLOGUE'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['VOLVO', 'XC90'],
#  ['RIVIAN', 'R1S'],
#  ['TESLA', 'MODEL Y'],
#  ['BMW', 'I4'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL Y'],
#  ['LINCOLN', 'AVIATOR'],
#  ['NISSAN', 'LEAF'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'LEAF'],
#  ['KIA', 'EV6'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['VOLVO', 'S90'],
#  ['VOLVO', 'XC60'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['JEEP', 'WRANGLER'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'ESCAPE'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['SUBARU', 'SOLTERRA'],
#  ['AUDI', 'E-TRON GT'],
#  ['RIVIAN', 'R1S'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'F-150'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'TRANSIT'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'FUSION'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'BLAZER EV'],
#  ['VOLVO', 'XC60'],
#  ['TESLA', 'MODEL 3'],
#  ['JEEP', 'WRANGLER'],
#  ['TESLA', 'MODEL S'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['LUCID', 'AIR'],
#  ['NISSAN', 'ARIYA'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['MERCEDES-BENZ', 'EQS-CLASS SEDAN'],
#  ['KIA', 'SPORTAGE'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'C-MAX'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['TESLA', 'MODEL S'],
#  ['BMW', 'I3'],
#  ['AUDI', 'Q5 E'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['FORD', 'FUSION'],
#  ['TESLA', 'MODEL 3'],
#  ['SUBARU', 'SOLTERRA'],
#  ['HYUNDAI', 'KONA'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['JEEP', 'GRAND CHEROKEE'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'SPORTAGE'],
#  ['TESLA', 'MODEL S'],
#  ['NISSAN', 'LEAF'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'LEAF'],
#  ['FORD', 'C-MAX'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['HYUNDAI', 'KONA ELECTRIC'],
#  ['HYUNDAI', 'IONIQ 6'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['BMW', 'I5'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['MERCEDES-BENZ', 'EQB-CLASS'],
#  ['TESLA', 'MODEL Y'],
#  ['AUDI', 'Q5 E'],
#  ['TESLA', 'MODEL Y'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL S'],
#  ['NISSAN', 'LEAF'],
#  ['FORD', 'C-MAX'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['MERCEDES-BENZ', 'C-CLASS'],
#  ['FORD', 'C-MAX'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL Y'],
#  ['BMW', 'I4'],
#  ['BMW', 'X3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['TOYOTA', 'BZ4X'],
#  ['FORD', 'F-150'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TESLA', 'MODEL X'],
#  ['MITSUBISHI', 'OUTLANDER'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['BMW', 'I4'],
#  ['TESLA', 'MODEL S'],
#  ['SUBARU', 'SOLTERRA'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['KIA', 'SOUL'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['MAZDA', 'CX-90'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['NISSAN', 'LEAF'],
#  ['RIVIAN', 'R1S'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['CADILLAC', 'LYRIQ'],
#  ['TESLA', 'MODEL 3'],
#  ['VOLVO', 'XC60'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLVO', 'XC60'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'ARIYA'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['FIAT', '500'],
#  ['TESLA', 'MODEL Y'],
#  ['MERCEDES-BENZ', 'EQB-CLASS'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['RIVIAN', 'R1S'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['TESLA', 'MODEL 3'],
#  ['VOLVO', 'XC60'],
#  ['BMW', 'IX'],
#  ['FORD', 'C-MAX'],
#  ['BMW', 'XM'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['VOLKSWAGEN', 'E-GOLF'],
#  ['CHRYSLER', 'PACIFICA'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL Y'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL X'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL Y'],
#  ['MAZDA', 'CX-90'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'VOLT'],
#  ['TESLA', 'MODEL Y'],
#  ['HYUNDAI', 'IONIQ 5'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', '530E'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL S'],
#  ['VOLVO', 'XC90'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'I4'],
#  ['NISSAN', 'LEAF'],
#  ['FORD', 'F-150'],
#  ['TESLA', 'MODEL 3'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['LAND ROVER', 'RANGE ROVER SPORT'],
#  ['RIVIAN', 'R1T'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['CHEVROLET', 'VOLT'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['NISSAN', 'LEAF'],
#  ['TOYOTA', 'BZ4X'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['KIA', 'NIRO'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['TESLA', 'MODEL X'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['RIVIAN', 'R1S'],
#  ['JEEP', 'WRANGLER'],
#  ['AUDI', 'E-TRON'],
#  ['NISSAN', 'LEAF'],
#  ['MITSUBISHI', 'OUTLANDER'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['VOLVO', 'XC90'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['JEEP', 'WRANGLER'],
#  ['BMW', 'I3'],
#  ['VOLVO', 'XC40'],
#  ['POLESTAR', 'PS2'],
#  ['TESLA', 'MODEL Y'],
#  ['HYUNDAI', 'TUCSON'],
#  ['BMW', 'X3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL S'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['BMW', 'X5'],
#  ['TOYOTA', 'RAV4 PRIME'],
#  ['CHEVROLET', 'EQUINOX EV'],
#  ['FORD', 'FUSION'],
#  ['RIVIAN', 'R1T'],
#  ['FIAT', '500'],
#  ['AUDI', 'E-TRON'],
#  ['TESLA', 'MODEL Y'],
#  ['VOLVO', 'XC40'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL 3'],
#  ['AUDI', 'E-TRON'],
#  ['PORSCHE', 'TAYCAN'],
#  ['TOYOTA', 'PRIUS PLUG-IN'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL S'],
#  ['JEEP', 'GRAND CHEROKEE'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['NISSAN', 'ARIYA'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL X'],
#  ['CHEVROLET', 'BOLT EUV'],
#  ['BMW', 'I3'],
#  ['TESLA', 'MODEL 3'],
#  ['MINI', 'HARDTOP'],
#  ['NISSAN', 'LEAF'],
#  ['NISSAN', 'LEAF'],
#  ['TESLA', 'MODEL Y'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'EV6'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'EQUINOX EV'],
#  ['FORD', 'TRANSIT'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'EV9'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['VOLKSWAGEN', 'ID.4'],
#  ['NISSAN', 'LEAF'],
#  ['VOLVO', 'C40'],
#  ['TESLA', 'MODEL 3'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'EV6'],
#  ['BMW', 'IX'],
#  ['TESLA', 'MODEL Y'],
#  ['CADILLAC', 'LYRIQ'],
#  ['TESLA', 'MODEL 3'],
#  ['CHEVROLET', 'VOLT'],
#  ['KIA', 'NIRO'],
#  ['JEEP', 'WRANGLER'],
#  ['TOYOTA', 'PRIUS PRIME'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['LUCID', 'AIR'],
#  ['TESLA', 'MODEL Y'],
#  ['CHEVROLET', 'BOLT EV'],
#  ['TESLA', 'MODEL S'],
#  ['VOLVO', 'XC40'],
#  ['TESLA', 'MODEL 3'],
#  ['HYUNDAI', 'IONIQ 6'],
#  ['RIVIAN', 'R1S'],
#  ['FORD', 'MUSTANG MACH-E'],
#  ['CHEVROLET', 'BLAZER EV'],
#  ['TESLA', 'MODEL S'],
#  ['TESLA', 'MODEL 3'],
#  ['KIA', 'NIRO'],
#  ...]

# %%
te = TransactionEncoder()
cm = te.fit(df_transactions_make_model).transform(df_transactions_make_model)
df_encoded_make_model = pd.DataFrame(cm, columns=te.columns_)


frequent_brand_model = apriori(df_encoded_make_model, min_support=0.001, use_colnames=True)

rules_brand_model = association_rules(frequent_brand_model, metric="confidence", min_threshold=0.5)

rules_brand_model
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 0        (330E)       (BMW)            0.002219            0.040963  0.002219
# 1         (500)      (FIAT)            0.003190            0.003392  0.003190
# 2        (FIAT)       (500)            0.003392            0.003190  0.003190
# 3        (530E)       (BMW)            0.001915            0.040963  0.001915
# 4          (A3)      (AUDI)            0.002479            0.018569  0.002479
# ..          ...         ...                 ...                 ...       ...
# 100  (SOLTERRA)    (SUBARU)            0.007763            0.008175  0.007763
# 101    (SUBARU)  (SOLTERRA)            0.008175            0.007763  0.007763
# 102      (XC40)     (VOLVO)            0.005790            0.024846  0.005790
# 103      (XC60)     (VOLVO)            0.006797            0.024846  0.006797
# 104      (XC90)     (VOLVO)            0.008533            0.024846  0.008533
#
#      confidence        lift  representativity  leverage  conviction  \
# 0      1.000000   24.412452               1.0  0.002128         inf
# 1      1.000000  294.849604               1.0  0.003179         inf
# 2      0.940633  294.849604               1.0  0.003179   16.790707
# 3      1.000000   24.412452               1.0  0.001837         inf
# 4      1.000000   53.854458               1.0  0.002433         inf
# ..          ...         ...               ...       ...         ...
# 100    1.000000  122.329502               1.0  0.007700         inf
# 101    0.949644  122.329502               1.0  0.007700   19.704533
# 102    1.000000   40.247794               1.0  0.005646         inf
# 103    1.000000   40.247794               1.0  0.006628         inf
# 104    1.000000   40.247794               1.0  0.008321         inf
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 0         0.961170  0.054178   1.000000    0.527089
# 1         0.999798  0.940633   1.000000    0.970317
# 2         1.000000  0.940633   0.940443    0.970317
# 3         0.960877  0.046750   1.000000    0.523375
# 4         0.983870  0.133494   1.000000    0.566747
# ..             ...       ...        ...         ...
# 100       0.999585  0.949644   1.000000    0.974822
# 101       1.000000  0.949644   0.949250    0.974822
# 102       0.980833  0.233027   1.000000    0.616514
# 103       0.981827  0.273546   1.000000    0.636773
# 104       0.983546  0.343418   1.000000    0.671709
#
# [105 rows x 14 columns]

# %%
filtered_rules = rules_brand_model[rules_brand_model['conviction'] == np.inf]
filtered_rules.sort_values(by=['lift'], ascending=True)
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 89        (MODEL Y)     (TESLA)            0.207950            0.429314
# 88        (MODEL X)     (TESLA)            0.027871            0.429314
# 87        (MODEL S)     (TESLA)            0.034631            0.429314
# 86        (MODEL 3)     (TESLA)            0.153819            0.429314
# 36     (CYBERTRUCK)     (TESLA)            0.004819            0.429314
# ..              ...         ...                 ...                 ...
# 5             (AIR)     (LUCID)            0.001597            0.001597
# 6           (LUCID)       (AIR)            0.001597            0.001597
# 55  (HUMMER EV SUV)       (GMC)            0.001007            0.001338
# 71         (I-PACE)    (JAGUAR)            0.001043            0.001043
# 70         (JAGUAR)    (I-PACE)            0.001043            0.001043
#
#      support  confidence        lift  representativity  leverage  conviction  \
# 89  0.207950         1.0    2.329297               1.0  0.118674         inf
# 88  0.027871         1.0    2.329297               1.0  0.015905         inf
# 87  0.034631         1.0    2.329297               1.0  0.019764         inf
# 86  0.153819         1.0    2.329297               1.0  0.087782         inf
# 36  0.004819         1.0    2.329297               1.0  0.002750         inf
# ..       ...         ...         ...               ...       ...         ...
# 5   0.001597         1.0  626.039216               1.0  0.001595         inf
# 6   0.001597         1.0  626.039216               1.0  0.001595         inf
# 55  0.001007         1.0  747.478261               1.0  0.001005         inf
# 71  0.001043         1.0  959.210300               1.0  0.001041         inf
# 70  0.001043         1.0  959.210300               1.0  0.001041         inf
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 89       0.720517  0.484377        1.0    0.742189
# 88       0.587047  0.064919        1.0    0.532460
# 87       0.591159  0.080667        1.0    0.540334
# 86       0.674425  0.358291        1.0    0.679145
# 36       0.573449  0.011225        1.0    0.505612
# ..            ...       ...        ...         ...
# 5        1.000000  1.000000        1.0    1.000000
# 6        1.000000  1.000000        1.0    1.000000
# 55       0.999669  0.752508        1.0    0.876254
# 71       1.000000  1.000000        1.0    1.000000
# 70       1.000000  1.000000        1.0    1.000000
#
# [90 rows x 14 columns]

# %% [markdown]
# **Findings:** Absolutely bound brand-model (Conviction = inf, confidence = 1.0) [Model → Brand]
#
# These models are already the brand's masterpieces, and the brand does not need to worry too much about customers buying other brands' cars. It is suitable to continue marketing and consolidate the brand image.

# %%
filtered_rules = rules_brand_model[rules_brand_model['conviction'] != np.inf]
filtered_rules.sort_values(by=['lift'], ascending=False)
# Out:
#       antecedents      consequents  antecedent support  consequent support  \
# 56          (GMC)  (HUMMER EV SUV)            0.001338            0.001007
# 2          (FIAT)            (500)            0.003392            0.003190
# 35        (MAZDA)          (CX-90)            0.004094            0.003732
# 24     (CADILLAC)          (LYRIQ)            0.004591            0.004201
# 85   (MITSUBISHI)      (OUTLANDER)            0.004761            0.004528
# 58         (MINI)        (HARDTOP)            0.004855            0.003606
# 91     (POLESTAR)            (PS2)            0.005459            0.005302
# 92      (PORSCHE)         (TAYCAN)            0.006099            0.003463
# 60        (HONDA)       (PROLOGUE)            0.008054            0.004170
# 101      (SUBARU)       (SOLTERRA)            0.008175            0.007763
# 73   (VOLKSWAGEN)           (ID.4)            0.025629            0.020770
# 75         (JEEP)       (WRANGLER)            0.025736            0.019128
# 96       (RIVIAN)            (R1S)            0.027848            0.014944
# 64      (HYUNDAI)        (IONIQ 5)            0.030721            0.016667
# 81       (NISSAN)           (LEAF)            0.068229            0.061410
#
#       support  confidence        lift  representativity  leverage  conviction  \
# 56   0.001007    0.752508  747.478261               1.0  0.001005    4.036473
# 2    0.003190    0.940633  294.849604               1.0  0.003179   16.790707
# 35   0.003732    0.911475  244.257923               1.0  0.003716   11.254143
# 24   0.004201    0.915205  217.832359               1.0  0.004182   11.743556
# 85   0.004528    0.951128  210.052632               1.0  0.004506   20.368888
# 58   0.003606    0.742857  205.987097               1.0  0.003589    3.874864
# 91   0.005302    0.971311  183.193443               1.0  0.005273   34.672327
# 92   0.003463    0.567865  163.973588               1.0  0.003442    2.306078
# 60   0.004170    0.517778  124.164444               1.0  0.004137    2.065085
# 101  0.007763    0.949644  122.329502               1.0  0.007700   19.704533
# 73   0.020770    0.810405   39.018156               1.0  0.020238    5.164852
# 75   0.019128    0.743220   38.855355               1.0  0.018636    3.819889
# 96   0.014944    0.536632   35.908740               1.0  0.014528    2.125862
# 64   0.016667    0.542528   32.551121               1.0  0.016155    2.149495
# 81   0.061410    0.900059   14.656436               1.0  0.057220    9.391438
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 56             1.0  0.752508   0.752259    0.876254
# 2              1.0  0.940633   0.940443    0.970317
# 35             1.0  0.911475   0.911144    0.955738
# 24             1.0  0.915205   0.914847    0.957602
# 85             1.0  0.951128   0.950906    0.975564
# 58             1.0  0.742857   0.741926    0.871429
# 91             1.0  0.971311   0.971159    0.985656
# 92             1.0  0.567865   0.566363    0.783933
# 60             1.0  0.517778   0.515758    0.758889
# 101            1.0  0.949644   0.949250    0.974822
# 73             1.0  0.810405   0.806384    0.905203
# 75             1.0  0.743220   0.738212    0.871610
# 96             1.0  0.536632   0.529603    0.768316
# 64             1.0  0.542528   0.534775    0.771264
# 81             1.0  0.900059   0.893520    0.950030

# %% [markdown]
# **Findings:** (Conviction = inf, confidence = 1.0) [Brand → Model]
#
# These cars have a strong relationship with the brand, but customers may have other options and are not 100% sure to buy this brand. There are competitors in the market, for example, people who buy NISSAN may not buy WRANGLER.

# %%
rules_brand_model['antecedents'] = rules_brand_model ['antecedents'].apply(lambda a: ','.join(list(a)))
rules_brand_model['consequents'] = rules_brand_model ['consequents'].apply(lambda a: ','.join(list(a)))

# %%
support_table = rules_brand_model.pivot(index='antecedents', columns='consequents',
values='support')

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 12))
sns.heatmap(support_table, annot=True, linewidths=0.5, linecolor='gray', cmap='coolwarm')
plt.show()

# %% [markdown]
# ###**b) Market Basket Analysis 2: Mining the relationship between Model and County.**

# %%
df_model_county = df_filtered[['Model', 'County']].copy()
df_transactions_model_county = df_model_county.astype(str).values.tolist()
df_transactions_model_county
# Out:
# [['WRANGLER', 'Kitsap'],
#  ['BOLT EV', 'Snohomish'],
#  ['I3', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'Yakima'],
#  ['WRANGLER', 'Kitsap'],
#  ['530E', 'Thurston'],
#  ['MODEL X', 'King'],
#  ['BOLT EV', 'Yakima'],
#  ['MODEL 3', 'Snohomish'],
#  ['LEAF', 'Snohomish'],
#  ['RZ', 'Kitsap'],
#  ['EV6', 'Kitsap'],
#  ['LEAF', 'Kitsap'],
#  ['LEAF', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL S', 'Kitsap'],
#  ['PS2', 'Island'],
#  ['MODEL S', 'King'],
#  ['SANTA FE', 'Kitsap'],
#  ['I3', 'Kitsap'],
#  ['MODEL Y', 'Yakima'],
#  ['MODEL X', 'King'],
#  ['WRANGLER', 'Kitsap'],
#  ['330E', 'Kitsap'],
#  ['PRIUS PRIME', 'Kitsap'],
#  ['MODEL 3', 'Kitsap'],
#  ['R1T', 'Thurston'],
#  ['XC60', 'Thurston'],
#  ['X5', 'King'],
#  ['500', 'Thurston'],
#  ['BOLT EUV', 'Yakima'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'Kitsap'],
#  ['BOLT EV', 'Kitsap'],
#  ['MODEL S', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL Y', 'Snohomish'],
#  ['CX-90', 'Kitsap'],
#  ['CX-90', 'Thurston'],
#  ['NIRO', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'Kitsap'],
#  ['MODEL X', 'King'],
#  ['MODEL X', 'Kitsap'],
#  ['XC90', 'Snohomish'],
#  ['MODEL Y', 'Thurston'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'Snohomish'],
#  ['R1S', 'Snohomish'],
#  ['LEAF', 'King'],
#  ['MODEL 3', 'Snohomish'],
#  ['E-TRON', 'Yakima'],
#  ['RX', 'Thurston'],
#  ['LEAF', 'Kitsap'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL 3', 'Thurston'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL X', 'King'],
#  ['BOLT EV', 'Yakima'],
#  ['I3', 'Kitsap'],
#  ['IX', 'Yakima'],
#  ['WRANGLER', 'Kitsap'],
#  ['X5', 'King'],
#  ['NIRO', 'Kitsap'],
#  ['LEAF', 'Kitsap'],
#  ['NIRO', 'Thurston'],
#  ['LEAF', 'Kitsap'],
#  ['MODEL Y', 'Yakima'],
#  ['MODEL 3', 'Snohomish'],
#  ['EV6', 'Kitsap'],
#  ['R1S', 'Yakima'],
#  ['LEAF', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['PACIFICA', 'Kitsap'],
#  ['LEAF', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['BOLT EV', 'Thurston'],
#  ['LEAF', 'Thurston'],
#  ['LEAF', 'Kitsap'],
#  ['MODEL S', 'King'],
#  ['IONIQ', 'Kitsap'],
#  ['MODEL S', 'Snohomish'],
#  ['SOUL', 'Thurston'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL 3', 'Thurston'],
#  ['MODEL 3', 'Kitsap'],
#  ['F-150', 'Snohomish'],
#  ['330E', 'Snohomish'],
#  ['MODEL S', 'Island'],
#  ['NIRO', 'Stevens'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['Q5 E', 'Thurston'],
#  ['WRANGLER', 'Thurston'],
#  ['MODEL Y', 'Kitsap'],
#  ['VOLT', 'Snohomish'],
#  ['MODEL Y', 'King'],
#  ['XC90', 'Kitsap'],
#  ['SORENTO', 'Snohomish'],
#  ['BOLT EV', 'Thurston'],
#  ['LEAF', 'Kitsap'],
#  ['GRAND CHEROKEE', 'Grant'],
#  ['WRANGLER', 'Grant'],
#  ['MODEL X', 'Snohomish'],
#  ['MODEL X', 'Snohomish'],
#  ['RAV4 PRIME', 'Stevens'],
#  ['SORENTO', 'Snohomish'],
#  ['LEAF', 'Yakima'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Island'],
#  ['500', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['X5', 'King'],
#  ['I3', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL X', 'Yakima'],
#  ['NIRO', 'Thurston'],
#  ['MODEL 3', 'Kitsap'],
#  ['X5', 'King'],
#  ['530E', 'Kitsap'],
#  ['MODEL S', 'Thurston'],
#  ['CX-90', 'Thurston'],
#  ['VOLT', 'Thurston'],
#  ['MODEL S', 'Thurston'],
#  ['MODEL 3', 'Kittitas'],
#  ['MODEL 3', 'Snohomish'],
#  ['SOUL', 'Yakima'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL X', 'Snohomish'],
#  ['SOUL', 'Thurston'],
#  ['GLC-CLASS', 'Snohomish'],
#  ['LEAF', 'Thurston'],
#  ['LEAF', 'Yakima'],
#  ['XC90', 'King'],
#  ['MODEL 3', 'Yakima'],
#  ['MODEL 3', 'King'],
#  ['SORENTO', 'Thurston'],
#  ['A3', 'King'],
#  ['MODEL 3', 'Yakima'],
#  ['MODEL X', 'King'],
#  ['RAV4 PRIME', 'Thurston'],
#  ['MODEL 3', 'Kitsap'],
#  ['CX-70', 'Spokane'],
#  ['MODEL Y', 'Yakima'],
#  ['MODEL Y', 'Whitman'],
#  ['500', 'Skagit'],
#  ['MODEL 3', 'Yakima'],
#  ['MODEL 3', 'Spokane'],
#  ['MODEL 3', 'Stevens'],
#  ['MODEL X', 'Thurston'],
#  ['CX-90', 'Douglas'],
#  ['I3', 'Snohomish'],
#  ['LEAF', 'Kitsap'],
#  ['NIRO', 'Snohomish'],
#  ['MODEL S', 'Island'],
#  ['CLARITY', 'Snohomish'],
#  ['RAV4 PRIME', 'Spokane'],
#  ['MODEL 3', 'Yakima'],
#  ['C-MAX', 'Snohomish'],
#  ['OUTLANDER', 'Whitman'],
#  ['MODEL S', 'Skagit'],
#  ['MODEL 3', 'Snohomish'],
#  ['RAV4 PRIME', 'Snohomish'],
#  ['PRIUS PLUG-IN', 'Walla Walla'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL Y', 'Snohomish'],
#  ['WRANGLER', 'Skagit'],
#  ['Q5', 'Kittitas'],
#  ['MODEL S', 'Grant'],
#  ['BOLT EV', 'Chelan'],
#  ['LEAF', 'Stevens'],
#  ['MODEL 3', 'Snohomish'],
#  ['PRIUS PRIME', 'Snohomish'],
#  ['LEAF', 'Thurston'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['LEAF', 'Thurston'],
#  ['MODEL S', 'Thurston'],
#  ['NX', 'Snohomish'],
#  ['LEAF', 'King'],
#  ['C-MAX', 'Island'],
#  ['BOLT EV', 'Whitman'],
#  ['PACIFICA', 'Grant'],
#  ['MODEL X', 'King'],
#  ['LEAF', 'Snohomish'],
#  ['X5', 'Chelan'],
#  ['MODEL S', 'Skagit'],
#  ['MODEL 3', 'Snohomish'],
#  ['Q5 E', 'Snohomish'],
#  ['SOUL', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['BOLT EV', 'Snohomish'],
#  ['MODEL X', 'Skagit'],
#  ['MODEL 3', 'Island'],
#  ['PACIFICA', 'Snohomish'],
#  ['LEAF', 'Island'],
#  ['MODEL 3', 'Yakima'],
#  ['LEAF', 'Skagit'],
#  ['BOLT EV', 'Skagit'],
#  ['MODEL 3', 'Snohomish'],
#  ['WRANGLER', 'Kitsap'],
#  ['MODEL 3', 'Skagit'],
#  ['MODEL 3', 'Snohomish'],
#  ['SPORTAGE', 'Skagit'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL Y', 'Spokane'],
#  ['MODEL X', 'Walla Walla'],
#  ['MODEL 3', 'Walla Walla'],
#  ['Q5 E', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['NIRO', 'Kitsap'],
#  ['SOUL', 'Thurston'],
#  ['LEAF', 'Thurston'],
#  ['SORENTO', 'Snohomish'],
#  ['I3', 'Snohomish'],
#  ['MODEL Y', 'Skagit'],
#  ['500', 'King'],
#  ['NX', 'Snohomish'],
#  ['MODEL 3', 'Thurston'],
#  ['MODEL Y', 'Snohomish'],
#  ['BOLT EV', 'Snohomish'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL 3', 'Snohomish'],
#  ['LEAF', 'Skagit'],
#  ['Q5 E', 'Thurston'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL 3', 'Thurston'],
#  ['LEAF', 'Thurston'],
#  ['MODEL 3', 'Grant'],
#  ['E-TRON', 'Snohomish'],
#  ['A3', 'Thurston'],
#  ['XC90', 'Chelan'],
#  ['EV6', 'Douglas'],
#  ['ID.4', 'King'],
#  ['ID.4', 'King'],
#  ['SOLTERRA', 'Kitsap'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['BOLT EV', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['ARIYA', 'King'],
#  ['E-GOLF', 'King'],
#  ['FUSION', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['IONIQ 5', 'Snohomish'],
#  ['LEAF', 'King'],
#  ['I3', 'Kitsap'],
#  ['SPARK', 'Kitsap'],
#  ['XC60', 'Thurston'],
#  ['MODEL Y', 'Cowlitz'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['LEAF', 'King'],
#  ['MUSTANG MACH-E', 'Jefferson'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['NIRO', 'King'],
#  ['CAYENNE', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'Kitsap'],
#  ['X5', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['F-150', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['ID.4', 'Yakima'],
#  ['BOLT EUV', 'King'],
#  ['EV6', 'Clark'],
#  ['MODEL S', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['TRANSIT', 'Kitsap'],
#  ['PRIUS PRIME', 'Thurston'],
#  ['VOLT', 'King'],
#  ['MODEL Y', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['BOLT EUV', 'Kitsap'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['LEAF', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['OUTLANDER', 'Kitsap'],
#  ['MODEL Y', 'Snohomish'],
#  ['BOLT EUV', 'King'],
#  ['MODEL 3', 'King'],
#  ['BOLT EUV', 'Clark'],
#  ['MODEL X', 'King'],
#  ['MODEL S', 'King'],
#  ['BZ4X', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['EQS-CLASS SEDAN', 'Snohomish'],
#  ['R1T', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['NIRO', 'King'],
#  ['745E', 'Snohomish'],
#  ['KONA ELECTRIC', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['BZ4X', 'Cowlitz'],
#  ['MODEL 3', 'Clark'],
#  ['IONIQ 5', 'Clark'],
#  ['FUSION', 'King'],
#  ['F-150', 'Kitsap'],
#  ['RAV4 PRIME', 'King'],
#  ['ID.4', 'Thurston'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'King'],
#  ['I-PACE', 'King'],
#  ['GRAND CHEROKEE', 'King'],
#  ['MODEL X', 'King'],
#  ['Q4', 'King'],
#  ['GRAND CHEROKEE', 'Kitsap'],
#  ['MODEL S', 'King'],
#  ['530E', 'King'],
#  ['VOLT', 'Snohomish'],
#  ['VOLT', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['EV6', 'King'],
#  ['MODEL Y', 'King'],
#  ['PRIUS PLUG-IN', 'King'],
#  ['EV6', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'Yakima'],
#  ['VOLT', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['EV9', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL X', 'King'],
#  ['MODEL S', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['IONIQ 5', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL X', 'Kitsap'],
#  ['TAYCAN', 'King'],
#  ['MODEL 3', 'King'],
#  ['VOLT', 'King'],
#  ['C-MAX', 'Jefferson'],
#  ['X5', 'King'],
#  ['V60', 'King'],
#  ['E-TRON', 'King'],
#  ['EV6', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['PRIUS PLUG-IN', 'Thurston'],
#  ['MODEL 3', 'King'],
#  ['OUTLANDER', 'Cowlitz'],
#  ['MUSTANG MACH-E', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['IX', 'Thurston'],
#  ['MODEL Y', 'King'],
#  ['NIRO', 'King'],
#  ['SQ8', 'Snohomish'],
#  ['I3', 'Clark'],
#  ['LEAF', 'King'],
#  ['FUSION', 'Clark'],
#  ['LEAF', 'Thurston'],
#  ['MODEL 3', 'King'],
#  ['MODEL X', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'Kitsap'],
#  ['NIRO', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['BZ4X', 'King'],
#  ['330E', 'King'],
#  ['MODEL Y', 'Kitsap'],
#  ['SOUL', 'King'],
#  ['VOLT', 'Jefferson'],
#  ['LEAF', 'King'],
#  ['IONIQ 5', 'Clark'],
#  ['MODEL S', 'King'],
#  ['EQS-CLASS SUV', 'King'],
#  ['MODEL Y', 'King'],
#  ['BOLT EUV', 'King'],
#  ['IONIQ 5', 'Kitsap'],
#  ['NX', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['SPORTAGE', 'Kitsap'],
#  ['MODEL Y', 'King'],
#  ['ARIYA', 'King'],
#  ['RZ', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'King'],
#  ['EV9', 'King'],
#  ['EV6', 'Yakima'],
#  ['NIRO', 'King'],
#  ['I4', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['BOLT EV', 'King'],
#  ['PRIUS PLUG-IN', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['Q5 E', 'King'],
#  ['BOLT EUV', 'King'],
#  ['LEAF', 'Jefferson'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['CLARITY', 'Clark'],
#  ['MODEL 3', 'Cowlitz'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'King'],
#  ['ID.4', 'King'],
#  ['MODEL 3', 'King'],
#  ['I3', 'King'],
#  ['MODEL 3', 'King'],
#  ['CX-90', 'King'],
#  ['MODEL Y', 'King'],
#  ['XC40', 'King'],
#  ['CLARITY', 'Clark'],
#  ['BOLT EV', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['WRANGLER', 'Stevens'],
#  ['XC40', 'King'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL X', 'King'],
#  ['BOLT EV', 'King'],
#  ['EQB-CLASS', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['XC90', 'King'],
#  ['MODEL 3', 'Thurston'],
#  ['FUSION', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['X5', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['TUCSON', 'King'],
#  ['MODEL 3', 'King'],
#  ['WRANGLER', 'King'],
#  ['BOLT EV', 'King'],
#  ['I4', 'Kitsap'],
#  ['MUSTANG MACH-E', 'King'],
#  ['WRANGLER', 'King'],
#  ['BOLT EV', 'Clark'],
#  ['VOLT', 'King'],
#  ['ID.4', 'King'],
#  ['EQUINOX EV', 'Snohomish'],
#  ['TAYCAN', 'King'],
#  ['KONA ELECTRIC', 'King'],
#  ['VOLT', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL Y', 'Yakima'],
#  ['BOLT EUV', 'King'],
#  ['MODEL 3', 'King'],
#  ['VOLT', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['PROLOGUE', 'King'],
#  ['MODEL X', 'King'],
#  ['I5', 'King'],
#  ['MODEL 3', 'King'],
#  ['HARDTOP', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['HUMMER EV PICKUP', 'King'],
#  ['RAV4 PRIME', 'Kitsap'],
#  ['MODEL X', 'King'],
#  ['MODEL S', 'King'],
#  ['TAYCAN', 'King'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'Snohomish'],
#  ['PRIUS PRIME', 'Kitsap'],
#  ['PRIUS PRIME', 'King'],
#  ['MODEL 3', 'King'],
#  ['AIR', 'Kitsap'],
#  ['F-150', 'Thurston'],
#  ['IONIQ 5', 'King'],
#  ['XC90', 'King'],
#  ['EV9', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['R1T', 'King'],
#  ['MODEL Y', 'King'],
#  ['E-GOLF', 'King'],
#  ['PS2', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['MODEL Y', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['MODEL 3', 'King'],
#  ['F-150', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'Kitsap'],
#  ['FOCUS', 'King'],
#  ['X5', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL Y', 'Thurston'],
#  ['IONIQ', 'Yakima'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['MODEL S', 'King'],
#  ['BLAZER EV', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['EV9', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL Y', 'King'],
#  ['PRIUS PRIME', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['BZ4X', 'Clark'],
#  ['PACIFICA', 'Yakima'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['BOLT EV', 'King'],
#  ['BOLT EV', 'Thurston'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL X', 'King'],
#  ['X5', 'King'],
#  ['SORENTO', 'King'],
#  ['PRIUS PRIME', 'King'],
#  ['ID.4', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MUSTANG MACH-E', 'Kitsap'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['F-150', 'Jefferson'],
#  ['MODEL Y', 'King'],
#  ['LYRIQ', 'King'],
#  ['MODEL Y', 'Jefferson'],
#  ['ARIYA', 'Snohomish'],
#  ['XC90', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['LEAF', 'King'],
#  ['XC90', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['VOLT', 'King'],
#  ['E-GOLF', 'King'],
#  ['PACIFICA', 'Snohomish'],
#  ['MODEL Y', 'King'],
#  ['XC90', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['SOUL', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['IX', 'King'],
#  ['MODEL S', 'King'],
#  ['IONIQ 5', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'King'],
#  ['RAV4 PRIME', 'Clark'],
#  ['BOLT EV', 'Thurston'],
#  ['LEAF', 'King'],
#  ['I-MIEV', 'King'],
#  ['LEAF', 'King'],
#  ['BOLT EUV', 'Kitsap'],
#  ['BOLT EV', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['I4', 'King'],
#  ['XC60', 'King'],
#  ['PRIUS PRIME', 'King'],
#  ['IX', 'King'],
#  ['MODEL Y', 'King'],
#  ['R1T', 'Kitsap'],
#  ['A3', 'King'],
#  ['MODEL X', 'King'],
#  ['SORENTO', 'King'],
#  ['MODEL 3', 'King'],
#  ['R1T', 'King'],
#  ['GLC-CLASS', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL Y', 'King'],
#  ['Q8', 'King'],
#  ['TRANSIT', 'Thurston'],
#  ['EV6', 'King'],
#  ['E-TRON', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['R1S', 'King'],
#  ['LYRIQ', 'King'],
#  ['NIRO', 'King'],
#  ['MODEL Y', 'King'],
#  ['FORTWO ELECTRIC DRIVE', 'King'],
#  ['WRANGLER', 'Snohomish'],
#  ['R1S', 'King'],
#  ['BOLT EV', 'King'],
#  ['LEAF', 'Jefferson'],
#  ['MODEL Y', 'King'],
#  ['F-150', 'King'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['Q5 E', 'King'],
#  ['VOLT', 'Yakima'],
#  ['LEAF', 'King'],
#  ['MODEL X', 'Clark'],
#  ['I-PACE', 'King'],
#  ['LEAF', 'King'],
#  ['EV6', 'Yakima'],
#  ['EV9', 'King'],
#  ['AVIATOR', 'Kitsap'],
#  ['CX-90', 'Snohomish'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['I4', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['PROLOGUE', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Thurston'],
#  ['ID.4', 'King'],
#  ['XC90', 'King'],
#  ['R1S', 'King'],
#  ['MODEL Y', 'King'],
#  ['I4', 'King'],
#  ['BOLT EV', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['AVIATOR', 'King'],
#  ['LEAF', 'King'],
#  ['E-GOLF', 'King'],
#  ['MODEL Y', 'King'],
#  ['LEAF', 'King'],
#  ['EV6', 'King'],
#  ['PACIFICA', 'King'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['S90', 'Clark'],
#  ['XC60', 'King'],
#  ['E-GOLF', 'King'],
#  ['WRANGLER', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['ESCAPE', 'King'],
#  ['E-GOLF', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL Y', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['SOLTERRA', 'King'],
#  ['E-TRON GT', 'King'],
#  ['R1S', 'King'],
#  ['MODEL Y', 'King'],
#  ['F-150', 'Jefferson'],
#  ['MODEL 3', 'King'],
#  ['TRANSIT', 'King'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'Thurston'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['FUSION', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['MODEL 3', 'King'],
#  ['BLAZER EV', 'Clark'],
#  ['XC60', 'King'],
#  ['MODEL 3', 'King'],
#  ['WRANGLER', 'King'],
#  ['MODEL S', 'King'],
#  ['ID.4', 'King'],
#  ['BOLT EV', 'King'],
#  ['MODEL Y', 'King'],
#  ['VOLT', 'King'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL Y', 'King'],
#  ['AIR', 'King'],
#  ['ARIYA', 'King'],
#  ['MODEL 3', 'Snohomish'],
#  ['VOLT', 'Thurston'],
#  ['MODEL 3', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['EQS-CLASS SEDAN', 'King'],
#  ['SPORTAGE', 'King'],
#  ['BOLT EV', 'Jefferson'],
#  ['MODEL Y', 'King'],
#  ['C-MAX', 'King'],
#  ['ID.4', 'King'],
#  ['MODEL S', 'Clark'],
#  ['I3', 'King'],
#  ['Q5 E', 'King'],
#  ['E-GOLF', 'Kitsap'],
#  ['FUSION', 'King'],
#  ['MODEL 3', 'King'],
#  ['SOLTERRA', 'King'],
#  ['KONA', 'Jefferson'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['GRAND CHEROKEE', 'Clark'],
#  ['MODEL 3', 'Clark'],
#  ['SPORTAGE', 'Snohomish'],
#  ['MODEL S', 'King'],
#  ['LEAF', 'King'],
#  ['NIRO', 'King'],
#  ['MODEL Y', 'King'],
#  ['LEAF', 'King'],
#  ['C-MAX', 'King'],
#  ['MODEL 3', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['KONA ELECTRIC', 'King'],
#  ['IONIQ 6', 'Snohomish'],
#  ['BOLT EUV', 'Clark'],
#  ['I5', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'Kitsap'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['EQB-CLASS', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['Q5 E', 'King'],
#  ['MODEL Y', 'King'],
#  ['NIRO', 'King'],
#  ['MODEL S', 'King'],
#  ['LEAF', 'King'],
#  ['C-MAX', 'Jefferson'],
#  ['MUSTANG MACH-E', 'Kitsap'],
#  ['LEAF', 'Yakima'],
#  ['MODEL Y', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['C-CLASS', 'Kitsap'],
#  ['C-MAX', 'King'],
#  ['BOLT EV', 'Thurston'],
#  ['MODEL Y', 'King'],
#  ['I4', 'King'],
#  ['X3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['LEAF', 'Snohomish'],
#  ['MODEL X', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['BZ4X', 'King'],
#  ['F-150', 'King'],
#  ['PRIUS PRIME', 'King'],
#  ['MODEL X', 'King'],
#  ['OUTLANDER', 'King'],
#  ['MUSTANG MACH-E', 'Thurston'],
#  ['I4', 'King'],
#  ['MODEL S', 'King'],
#  ['SOLTERRA', 'King'],
#  ['PACIFICA', 'Clark'],
#  ['SOUL', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['PRIUS PRIME', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['CX-90', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL X', 'King'],
#  ['LEAF', 'Thurston'],
#  ['R1S', 'King'],
#  ['MODEL 3', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['LYRIQ', 'Thurston'],
#  ['MODEL 3', 'Snohomish'],
#  ['XC60', 'King'],
#  ['VOLT', 'King'],
#  ['MODEL Y', 'King'],
#  ['XC60', 'Kitsap'],
#  ['IONIQ 5', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['ARIYA', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['BOLT EV', 'King'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL Y', 'King'],
#  ['500', 'King'],
#  ['MODEL Y', 'King'],
#  ['EQB-CLASS', 'King'],
#  ['MODEL Y', 'Snohomish'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['PACIFICA', 'Kitsap'],
#  ['MODEL Y', 'King'],
#  ['ID.4', 'King'],
#  ['R1S', 'King'],
#  ['PRIUS PRIME', 'King'],
#  ['MODEL 3', 'Kitsap'],
#  ['XC60', 'King'],
#  ['IX', 'Kitsap'],
#  ['C-MAX', 'Kitsap'],
#  ['XM', 'King'],
#  ['PRIUS PRIME', 'King'],
#  ['BOLT EUV', 'Clark'],
#  ['E-GOLF', 'King'],
#  ['PACIFICA', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL Y', 'King'],
#  ['RAV4 PRIME', 'Clark'],
#  ['XC90', 'King'],
#  ['MODEL Y', 'King'],
#  ['I3', 'Snohomish'],
#  ['MODEL X', 'King'],
#  ['MODEL Y', 'King'],
#  ['BOLT EUV', 'King'],
#  ['MODEL Y', 'Kitsap'],
#  ['CX-90', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'King'],
#  ['VOLT', 'Snohomish'],
#  ['MODEL Y', 'Clark'],
#  ['IONIQ 5', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['530E', 'King'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL S', 'King'],
#  ['XC90', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL 3', 'King'],
#  ['I4', 'King'],
#  ['LEAF', 'King'],
#  ['F-150', 'Thurston'],
#  ['MODEL 3', 'King'],
#  ['ID.4', 'King'],
#  ['RANGE ROVER SPORT', 'King'],
#  ['R1T', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['VOLT', 'King'],
#  ['PRIUS PRIME', 'King'],
#  ['LEAF', 'King'],
#  ['BZ4X', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'Clark'],
#  ['LEAF', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['NIRO', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['LEAF', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['MODEL X', 'King'],
#  ['I3', 'King'],
#  ['MODEL Y', 'King'],
#  ['BOLT EUV', 'King'],
#  ['R1S', 'Snohomish'],
#  ['WRANGLER', 'King'],
#  ['E-TRON', 'Kitsap'],
#  ['LEAF', 'Clark'],
#  ['OUTLANDER', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'King'],
#  ['BOLT EUV', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['XC90', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'King'],
#  ['WRANGLER', 'Clark'],
#  ['I3', 'King'],
#  ['XC40', 'Kitsap'],
#  ['PS2', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['TUCSON', 'King'],
#  ['X3', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL S', 'Yakima'],
#  ['BOLT EUV', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'King'],
#  ['X5', 'King'],
#  ['RAV4 PRIME', 'King'],
#  ['EQUINOX EV', 'King'],
#  ['FUSION', 'Cowlitz'],
#  ['R1T', 'King'],
#  ['500', 'Yakima'],
#  ['E-TRON', 'King'],
#  ['MODEL Y', 'King'],
#  ['XC40', 'Clark'],
#  ['BOLT EV', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['E-TRON', 'King'],
#  ['TAYCAN', 'Clark'],
#  ['PRIUS PLUG-IN', 'Clark'],
#  ['MODEL 3', 'King'],
#  ['MODEL S', 'King'],
#  ['GRAND CHEROKEE', 'Kitsap'],
#  ['MODEL 3', 'King'],
#  ['MODEL Y', 'Clark'],
#  ['MODEL 3', 'Clark'],
#  ['ARIYA', 'King'],
#  ['MODEL Y', 'King'],
#  ['MODEL X', 'King'],
#  ['BOLT EUV', 'King'],
#  ['I3', 'King'],
#  ['MODEL 3', 'Clark'],
#  ['HARDTOP', 'King'],
#  ['LEAF', 'King'],
#  ['LEAF', 'Clark'],
#  ['MODEL Y', 'King'],
#  ['MODEL 3', 'King'],
#  ['EV6', 'King'],
#  ['MODEL 3', 'King'],
#  ['EQUINOX EV', 'Kitsap'],
#  ['TRANSIT', 'King'],
#  ['MODEL 3', 'King'],
#  ['EV9', 'Clark'],
#  ['ID.4', 'King'],
#  ['ID.4', 'Thurston'],
#  ['LEAF', 'King'],
#  ['C40', 'King'],
#  ['MODEL 3', 'King'],
#  ['MODEL 3', 'Snohomish'],
#  ['EV6', 'Clark'],
#  ['IX', 'King'],
#  ['MODEL Y', 'King'],
#  ['LYRIQ', 'King'],
#  ['MODEL 3', 'King'],
#  ['VOLT', 'King'],
#  ['NIRO', 'King'],
#  ['WRANGLER', 'Clark'],
#  ['PRIUS PRIME', 'Clark'],
#  ['BOLT EV', 'King'],
#  ['AIR', 'King'],
#  ['MODEL Y', 'King'],
#  ['BOLT EV', 'King'],
#  ['MODEL S', 'King'],
#  ['XC40', 'King'],
#  ['MODEL 3', 'King'],
#  ['IONIQ 6', 'King'],
#  ['R1S', 'King'],
#  ['MUSTANG MACH-E', 'King'],
#  ['BLAZER EV', 'King'],
#  ['MODEL S', 'King'],
#  ['MODEL 3', 'Kitsap'],
#  ['NIRO', 'King'],
#  ...]

# %%
te = TransactionEncoder()
mc = te.fit(df_transactions_model_county).transform(df_transactions_model_county)
df_encoded_model_county = pd.DataFrame(mc, columns=te.columns_)


frequent_model_county = apriori(df_encoded_model_county, min_support=0.001, use_colnames=True)

rules_model_county = association_rules(frequent_model_county, metric="lift", min_threshold= 1)

# %%
rules_model_county.sort_values(by=["support", "confidence"], ascending=False)
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 81     (MODEL Y)      (King)            0.207950            0.506291
# 80        (King)   (MODEL Y)            0.506291            0.207950
# 75     (MODEL 3)      (King)            0.153819            0.506291
# 74        (King)   (MODEL 3)            0.506291            0.153819
# 119  (Snohomish)   (MODEL Y)            0.121631            0.207950
# ..           ...         ...                 ...                 ...
# 25       (Clark)       (EV6)            0.060167            0.014322
# 136   (SOLTERRA)   (Spokane)            0.007763            0.028157
# 137    (Spokane)  (SOLTERRA)            0.028157            0.007763
# 53      (FUSION)    (Pierce)            0.007696            0.080655
# 52      (Pierce)    (FUSION)            0.080655            0.007696
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 81   0.114168    0.549015  1.084385               1.0  0.008884    1.094734
# 80   0.114168    0.225498  1.084385               1.0  0.008884    1.022657
# 75   0.083317    0.541655  1.069848               1.0  0.005440    1.077155
# 74   0.083317    0.164563  1.069848               1.0  0.005440    1.012860
# 119  0.032748    0.269239  1.294731               1.0  0.007455    1.083870
# ..        ...         ...       ...               ...       ...         ...
# 25   0.001056    0.017550  1.225380               1.0  0.000194    1.003286
# 136  0.001047    0.134870  4.789922               1.0  0.000828    1.123349
# 137  0.001047    0.037184  4.789922               1.0  0.000828    1.030557
# 53   0.001011    0.131395  1.629110               1.0  0.000390    1.058416
# 52   0.001011    0.012537  1.629110               1.0  0.000390    1.004903
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 81        0.098250  0.190256   0.086536    0.387256
# 80        0.157621  0.190256   0.022155    0.387256
# 75        0.077156  0.144448   0.071628    0.353109
# 74        0.132240  0.144448   0.012697    0.353109
# 119       0.259160  0.110324   0.077381    0.213359
# ..             ...       ...        ...         ...
# 25        0.195701  0.014380   0.003275    0.045639
# 136       0.797419  0.030023   0.109805    0.086027
# 137       0.814152  0.030023   0.029651    0.086027
# 53        0.389163  0.011578   0.055192    0.071966
# 52        0.420047  0.011578   0.004879    0.071966
#
# [140 rows x 14 columns]

# %% [markdown]
# **Finding:** Example:
#
# 1. **MODEL Y → King (support: 11.4%, confidence: 54.9%, lift: 1.08)**
# * Support = 0.114168 (≈11.4%): indicates that the probability of MODEL Y appearing in King County is 11.4%.
# * Confidence = 0.549015 (≈54.9%): indicates that when MODEL Y transactions occur, 54.9% of them occur in King County.
# * Lift = 1.08: indicates that the frequency of MODEL Y in King County is 8% higher than random.
#
# 2. **King → MODEL Y (support: 11.4%, confidence: 22.5%, lift: 1.08)**
#
# * Confidence = 0.225498 (≈22.5%): 22.5% of cars traded in King County are MODEL Y.
#
# * Lift = 1.08: MODEL Y trades in King County are still 8% higher than chance.
#
# * King County is not particularly biased towards MODEL Y, as confidence = 22.5% means there are many other models in King County.
#
# * But MODEL Y is still more common in King County than expected (lift = 1.08).

# %%
rules_model_county['antecedents'] = rules_model_county ['antecedents'].apply(lambda a: ','.join(list(a)))
rules_model_county['consequents'] = rules_model_county ['consequents'].apply(lambda a: ','.join(list(a)))

# %%
support_table = rules_model_county.pivot(index='antecedents', columns='consequents',
values='support')

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 12))
sns.heatmap(support_table, annot=True, linewidths=0.5, linecolor='gray', cmap='coolwarm')
plt.show()
